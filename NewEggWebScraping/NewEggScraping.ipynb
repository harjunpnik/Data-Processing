# %% [markdown]
# # Scraping

# %% [markdown]
# This program wevscrapes a site, in this case new eggs graphic cards site, and returns a list of all the graphic cards in the featured box.
# The site we will be scraping is [https://www.newegg.com/Video-Cards-Video-Devices/Category/ID-38?Tpk=graphics%20card](https://www.newegg.com/Video-Cards-Video-Devices/Category/ID-38?Tpk=graphics%20card).
#
# Lets start by importing the libraries that are needed.

# %% [markdown]
# ## Libraries

# %%
import bs4
from urllib.request import urlopen as uReq
from bs4 import BeautifulSoup as soup

# %% [markdown]
# ## A fecth of the site

# %%
newegg_url = "https://www.newegg.com/Video-Cards-Video-Devices/Category/ID-38?Tpk=graphics%20card"
uClient = uReq(newegg_url)
page_html = uClient.read()
uClient.close()
# preview of the page
page_html
# Out:
# b'<!DOCTYPE HTML>\r\n<html lang="en-us">\r\n<head>\r\n<script src="//imk.neweggimages.com/WebResource/Scripts/usa/strc/usa_prod/d2f967b83a0c92b19d9b572545fdbdc3d591f6f5/biztralib.js"></script>\r\n\t<title>Graphics Cards and Video Cards - Newegg.com</title>\r\n\t<meta http-equiv="Content-Type" content="text/html; charset=UTF-8">\r\n\t<meta name="referrer" content="always">\r\n\t<meta name="keywords" content="Graphics Cards, Video Cards">\r\n\t<meta name="description" content="Shop a wide selection of Video Graphics Cards from EVGA, Gigabyte, MSI &amp; more! Newegg offers the best prices, fast shipping and top-rated customer service!">\r\n\t<meta property="og:image" content="https://c1.neweggimages.com/WebResource/Themes/2005/Nest/logo_424x210.png">\r\n\t<meta property="og:description" content="Shop a wide selection of Video Graphics Cards from EVGA, Gigabyte, MSI &amp; more! Newegg offers the best prices, fast shipping and top-rated customer service!">\r\n\t<meta name="language" content="english">\r\n\t<meta name="copyright" content="&copy; 2000-2019 Newegg Inc.">\r\n\t<meta http-equiv="X-UA-Compatible" content="IE=edge">\r\n\t<meta name="robots" content="index,follow">\r\n\t<link rel="canonical" href="https://www.newegg.com/Video-Cards-Video-Devices/Category/ID-38">\r\n\t<meta name="X-DNS-Prefetch-Control" content="on">\r\n\t<link rel="shortcut icon" type="image/x-icon" href="//c1.neweggimages.com/WebResource/Themes/2005/Nest/Newegg.ico">\r\n\t<link href="//c1.neweggimages.com/WebResource/Themes/2005/Nest/logo_144x144.png" rel="apple-touch-icon-precomposed" sizes="144x144" />\r\n\t<link href="//c1.neweggimages.com/WebResource/Themes/2005/Nest/logo_120x120.png" rel="apple-touch-icon-precomposed" sizes="120x120" />\r\n\t<link href="//c1.neweggimages.com/WebResource/Themes/2005/Nest/logo_114x114.png" rel="apple-touch-icon-precomposed" sizes="114x114" />\r\n\t<link href="//c1.neweggimages.com/WebResource/Themes/2005/Nest/logo_72x72.png" rel="apple-touch-icon-precomposed" sizes="72x72" />\r\n\t<link href="//c1.neweggimages.com/WebResource/Themes/2005/Nest/logo_57x57.png" rel="apple-touch-icon-precomposed" sizes="57x57" />\r\n\t<link href="//c1.neweggimages.com/WebResource/Themes/2005/Nest/logo_57x57.png" rel="apple-touch-icon-precomposed" />\r\n\t<link rel="stylesheet" type="text/css" href="//c1.neweggimages.com/WebResource/Themes/2005/CSS/USA/WWWShared.30483.3.min.css"/>\r\n\t<link rel="stylesheet" type="text/css" href="//c1.neweggimages.com/WebResource/Themes/2005/CSS/USA/WWWStorePages2016.30365.6.min.css"/>\r\n\t<script type="text/javascript">var nebs = nebs||{};nebs.errors = [];window.onerror = function(){nebs.errors.push(arguments);return true;};</script>\r\n\t<script type="text/javascript">!function(i){var t=function(t){this._options={checkOnLoad:!1,resetOnEnd:!1,loopCheckTime:50,loopMaxNumber:5,baitClass:"pub_300x250 pub_300x250m pub_728x90 text-ad textAd text_ad text_ads text-ads text-ad-links",baitStyle:"width: 1px !important; height: 1px !important; position: absolute !important; left: -10000px !important; top: -1000px !important;",debug:!1},this._var={version:"3.2.1",bait:null,checking:!1,loop:null,loopNumber:0,event:{detected:[],notDetected:[]}},void 0!==t&&this.setOption(t);var e=this,o=function(){setTimeout(function(){!0===e._options.checkOnLoad&&(!0===e._options.debug&&e._log("onload->eventCallback","A check loading is launched"),null===e._var.bait&&e._creatBait(),setTimeout(function(){e.check()},1))},1)};void 0!==i.addEventListener?i.addEventListener("DOMContentLoaded",o,!1):i.attachEvent("onDOMContentLoaded",o)};t.prototype._options=null,t.prototype._var=null,t.prototype._bait=null,t.prototype._log=function(t,e){console.log("[BlockAdBlock]["+t+"] "+e)},t.prototype.setOption=function(t,e){if(void 0!==e){var o=t;(t={})[o]=e}for(var i in t)this._options[i]=t[i],!0===this._options.debug&&this._log("setOption",\'The option "\'+i+\'" he was assigned to "\'+t[i]+\'"\');return this},t.prototype._creatBait=function(){var t= ...

# %% [markdown]
# ## Parse the data to a bs4 soup element

# %%
page_soup = soup(page_html, 'html.parser')
# preview of the page
page_soup
# Out:
# <!DOCTYPE HTML>
#
# <html lang="en-us">
# <head>
# <script src="//imk.neweggimages.com/WebResource/Scripts/usa/strc/usa_prod/d2f967b83a0c92b19d9b572545fdbdc3d591f6f5/biztralib.js"></script>
# <title>Graphics Cards and Video Cards - Newegg.com</title>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="always" name="referrer"/>
# <meta content="Graphics Cards, Video Cards" name="keywords"/>
# <meta content="Shop a wide selection of Video Graphics Cards from EVGA, Gigabyte, MSI &amp; more! Newegg offers the best prices, fast shipping and top-rated customer service!" name="description"/>
# <meta content="https://c1.neweggimages.com/WebResource/Themes/2005/Nest/logo_424x210.png" property="og:image"/>
# <meta content="Shop a wide selection of Video Graphics Cards from EVGA, Gigabyte, MSI &amp; more! Newegg offers the best prices, fast shipping and top-rated customer service!" property="og:description"/>
# <meta content="english" name="language"/>
# <meta content="© 2000-2019 Newegg Inc." name="copyright"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="index,follow" name="robots"/>
# <link href="https://www.newegg.com/Video-Cards-Video-Devices/Category/ID-38" rel="canonical"/>
# <meta content="on" name="X-DNS-Prefetch-Control"/>
# <link href="//c1.neweggimages.com/WebResource/Themes/2005/Nest/Newegg.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="//c1.neweggimages.com/WebResource/Themes/2005/Nest/logo_144x144.png" rel="apple-touch-icon-precomposed" sizes="144x144">
# <link href="//c1.neweggimages.com/WebResource/Themes/2005/Nest/logo_120x120.png" rel="apple-touch-icon-precomposed" sizes="120x120">
# <link href="//c1.neweggimages.com/WebResource/Themes/2005/Nest/logo_114x114.png" rel="apple-touch-icon-precomposed" sizes="114x114"/>
# <link href="//c1.neweggimages.com/WebResource/Themes/2005/Nest/logo_72x72.png" rel="apple-touch-icon-precomposed" sizes="72x72"/>
# <link href="//c1.neweggimages.com/WebResource/Themes/2005/Nest/logo_57x57.png" rel="apple-touch-icon-precomposed" sizes="57x57"/>
# <link href="//c1.neweggimages.com/WebResource/Themes/2005/Nest/logo_57x57.png" rel="apple-touch-icon-precomposed"/>
# <link href="//c1.neweggimages.com/WebResource/Themes/2005/CSS/USA/WWWShared.30483.3.min.css" rel="stylesheet" type="text/css"/>
# <link href="//c1.neweggimages.com/WebResource/Themes/2005/CSS/USA/WWWStorePages2016.30365.6.min.css" rel="stylesheet" type="text/css"/>
# <script type="text/javascript">var nebs = nebs||{};nebs.errors = [];window.onerror = function(){nebs.errors.push(arguments);return true;};</script>
# <script type="text/javascript">!function(i){var t=function(t){this._options={checkOnLoad:!1,resetOnEnd:!1,loopCheckTime:50,loopMaxNumber:5,baitClass:"pub_300x250 pub_300x250m pub_728x90 text-ad textAd text_ad text_ads text-ads text-ad-links",baitStyle:"width: 1px !important; height: 1px !important; position: absolute !important; left: -10000px !important; top: -1000px !important;",debug:!1},this._var={version:"3.2.1",bait:null,checking:!1,loop:null,loopNumber:0,event:{detected:[],notDetected:[]}},void 0!==t&&this.setOption(t);var e=this,o=function(){setTimeout(function(){!0===e._options.checkOnLoad&&(!0===e._options.debug&&e._log("onload->eventCallback","A check loading is launched"),null===e._var.bait&&e._creatBait(),setTimeout(function(){e.check()},1))},1)};void 0!==i.addEventListener?i.addEventListener("DOMContentLoaded",o,!1):i.attachEvent("onDOMContentLoaded",o)};t.prototype._options=null,t.prototype._var=null,t.prototype._bait=null,t.prototype._log=function(t,e){console.log("[BlockAdBlock]["+t+"] "+e)},t.prototype.setOption=function(t,e){if(void 0!==e){var o=t;(t={})[o]=e}for(var i in t)this._options[i]=t[i],!0===this._options.debug&&this._log("setOption",'The option "'+i+'" he was assigned to "'+t[i]+'"');return this},t.prototype._creatBait=function(){var t=document.createElement("div");t.setAttribute("class",this._options.baitClass),t.setAttribute("style",this._options.baitStyle),this._var.bait=i.document.body.appendChild(t),this._var.bait.offsetParent,this._var.bait.offsetHeight,this._var.bait.offsetLeft,this._var.bait.offsetTop,this._var.bait.offsetWidth,this._var.bait.clientHeight,this._var.bait.clientWidth,!0===this._options.debug&&this._log("_creatBait","Bait has been created")},t.prototype._destroyBait=function(){i.document.body.removeChild(this._var.bait),!(this._var.bait=null)===this._options.debug&&this._log("_destroyBait","Bait has been removed")},t.prototype.check=function(t){if(void 0===t&&(t=!0),!0===this._options.debug&&this._log("check","An audit was requested "+(!0===t?"with a":"without")+" loop"),!0===this._var.checking)return!0===this._options.debug&&this._log("check","A check was canceled because there is already an ongoing"),!1;this._var.checking=!0,null===this._var.bait&&this._creatBait();var e=this;return!(this._var.loopNumber=0)===t&&(this._var.loop=setInterval(function(){e._checkBait(t)},this._options.loopCheckTime)),setTimeout(function(){e._checkBait(t)},1),!0===this._options.debug&&this._log("check","A check is in progress ..."),!0},t.prototype._checkBait=function(t){var e=!1;if(null===this._var.bait&&this._creatBait(),null===i.document.body.getAttribute("abp")&&null!==this._var.bait.offsetParent&&0!=this._var.bait.offsetHeight&&0!=this._var.bait.offsetLeft&&0!=this._var.bait.offsetTop&&0!=this._var.bait.offsetWidth&&0!=this._var.bait.clientHeight&&0!=this._var.bait.clientWidth||(e=!0),void 0!==i.getComputedStyle){var o=i.getComputedStyle(this._var.bait,null);!o||"none"!=o.getPropertyValue("display")&&"hidden"!=o.getPropertyValue("visibility")||(e=!0)}!0===this._options.debug&&this._log("_checkBait","A check ("+(this._var.loopNumber+1)+"/"+this._options.loopMaxNumber+" ~"+(1+this._var.loopNumber*this._options.loopCheckTime)+"ms) was conducted and detection is "+(!0===e?"positive":"negative")),!0===t&&(this._var.loopNumber++,this._var.loopNumber>=this._options.loopMaxNumber&&this._stopLoop()),!0===e?(this._stopLoop(),this._destroyBait(),this.emitEvent(!0),!0===t&&(this._var.checking=!1)):null!==this._var.loop&&!1!==t||(this._destroyBait(),this.emitEvent(!1),!0===t&&(this._var.checking=!1))},t.prototype._stopLoop=function(t){clearInterval(this._var.loop),this._var.loop=null,!(this._var.loopNumber=0)===this._options.debug&&this._log("_stopLoop","A loop has been stopped")},t.prototype.emitEvent=function(t){!0===this._options.debug&&this._log("emitEvent","An event with a "+(!0===t?"positive":"negative")+" detection was called");var e=this._var.event[!0===t?"detected":"notDetected"];for(var o in e)! ...
# <script crossorigin="anonymous" id="negJsID" onerror="NEGOnError()" src="//c1.neweggimages.com/WebResource/Scripts/USA/NeweggJS/NEG.0.2.4.js" type="text/javascript"></script>
# <script type="text/javascript">(function(NEG){if(NEG && NEG.setVersion){NEG.setVersion([{"module":"Biz.Cookie","version":"12376"},{"module":"Biz.Storage","version":"30394"},{"module":"Biz.InvodoVideo","version":"9792"},{"module":"Biz.Items","version":"9792"},{"module":"Biz.Resource","version":"9792"},{"module":"Biz.SearchKeywords","version":"9792"},{"module":"NEG.Utility.QueryStringBuilder","version":"11847"},{"module":"NEG.Widget.History","version":"9792"},{"module":"NEG.Widget.ImageZoomer","version":"13375.e0"},{"module":"NEG.Widget.Mask","version":"10825"},{"module":"NEG.Widget.RangeSlider","version":"12739.0"},{"module":"NEG.Widget.Scroll","version":"9792"},{"module":"NEG.Widget.Viewport","version":"9792"},{"module":"NEG.Widget.Popup","version":"11629"},{"module":"Widget.Switch","version":"11315"},{"module":"NEG.Widget.AutoConfigurator","version":"10825.1"},{"module":"NEG.Widget.FilterManager.Model","version":"10520"},{"module":"NEG.Widget.FilterManager.View","version":"10520"},{"module":"NEG.Widget.PropertyManager.Model","version":"10520.2"},{"module":"NEG.Widget.PropertyManager.ViewManager","version":"10520.2"},{"module":"Utility.Cookie","version":"14421"},{"module":"Utility.JQuery","version":"12376"},{"module":"NEG.ThirdParty.JQuery","version":"12376"},{"module":"Biz.Common.Popup","version":"13760.1"},{"module":"Biz.Common.RecentlyView2016","version":"30483.1"},{"module":"Biz.Common.RecentlyView2012","version":"13025.1"},{"module":"Biz.Product.ProductPersonalization","version":"30474.3"},{"module":"Biz.Product.MiniFeatures","version":"14303.0"},{"module":"NEG.Widget.Drone","version":"14303.1"},{"module":"NEG.Widget.Drone.DroneConfig","version":"30483.0"}]);}})(NEG);</script>
# <script crossorigin="anonymous" src="//c1.neweggimages.com/WebResource/Scripts/USA/TP_jQueryPlugin/jquery-1.12.4.min.js" type="text/javascript"></script>
# <script type="text/javascript">if(!(typeof jQuery==='undefined')){if($===jQuery){jQuery.noConflict();}}</script>
# <script crossorigin="anonymous" src="//c1.neweggimages.com/WebResource/Scripts/USA/TP_jQueryPlugin/jquery-migrate-1.2.1.min.js" type="text/javascript"></script>
# <script crossorigin="anonymous" src="//c1.neweggimages.com/WebResource/Scripts/USA/TP_jQueryPlugin/popup.v1.w.30007.0.js" type="text/javascript"></script>
# <script type="text/javascript">var nt_serverName="E11WEB02";var CANSite="//www.newegg.ca";var DOMAIN_NAME=".newegg.com",DOMAIN_TEXT="Newegg.com";if(!window["Web"]){Web={};};Web["Config"]={Environment:{Url:{WWW:'https://www.newegg.com/',Shopper:'https://secure.newegg.com/',Secure:'https://secure.newegg.com/',Content:'https://www.newegg.com/',CDN:'https://www2.newegg.com/',HttpCache:'//c1.neweggimages.com/WebResource/',HttpsCache:'//c1.neweggimages.com/WebResource/',HttpJSCache:'//c1.neweggimages.com/WebResource/',HttpsJSCache:'//c1.neweggimages.com/WebResource/',Local:'/WebResource/',Language:'en-US',ProductList:'p/pl',ProductDetail:'{Keywords}p/{ParentItemNumber}'},SSLPage:{Login:'https://secure.newegg.com/NewMyAccount/AccountLogin.aspx?nextpage=https%3a%2f%2fwww.newegg.com%2fVideo-Cards-Video-Devices%2fCategory%2fID-38',Loginout:'https://secure.newegg.com/NewMyAccount/AccountLogout.aspx',MyAccountIndex:'https://secure.newegg.com/NewMyAccount/Index.aspx',Shoppingcart:'https://secure.newegg.com/Shopping/ShoppingCart.aspx',AddTocart:'https://secure.newegg.com/Shopping/AddToCart.aspx',ActivePoint:'https://secure.newegg.com/NewMyAccount/ActivePoints.aspx',NewMyAccountAutoNotify:'https://secure.newegg.com/NewMyAccount/AutoNotify.aspx'},Path:{Images:'Themes/2005/Nest/',Scripts:'Scripts/',Css:'Themes/2005/CSS/'},Cookies:{EnableCookieNameMapping:1},AutoFillBold:{Enable:true,UseContentPage:true},IE11VersionUpgrade:true,SwitchCountrySelectorPopup:true,SearchInputRequestTimeInterval:700,NeweggGlobalUrl:'http://promotions.newegg.com/international/global/index.html',WWWPage:{B2BSepEnable: false,IsHomepage: false,IsProductList: false,IsNewStoreAndList: false,IsDailyDealStore: false,IsSubcategory: false,NeweggGlobalStore:'https://www.newegg.com/Newegg-Global/Store',IsVatAllPages:false,ProductListEnableRightSide:true},SyncShoppingCart:{MinicartServiceEnable:true,ItemPriceLink:'https://secure.newegg.com/Common/Ajax/MiniCartService.aspx',ItemDetailLink:'https://secure.newegg.com/Common/Ajax/MiniCartService.aspx?IsDetail=true',}},CookieMapping:{'NV_CONFIGURATION':['.newegg.com',86400000,'',false,0],'NV_PRDLIST':['.newegg.com',86400000,'',false,0],'NV_ADVSEARCHOPEN':['.newegg.com',86400000,'',false,0],'NV_CUSTOMERLOGIN':['.newegg.com',0,'',true,0],'NV_AFFILIATECUSTOMER':['.newegg.com',604800,'',false,0],'NV_HBXCM':['.newegg.com',86400000,'',false,0],'NV_ADVSEARCHOPEN':['.newegg.com',86400000,'',false,0],'NV_CONTACTUS_COOKIE':['.newegg.com',86400000,'',false,0],'NV_VENDOR_NEWS_LIST':['.newegg.com',86400000,'',false,0],'CELL_PHONE_COMBO':['.newegg.com',86400000,'',false,0],'CELL_PHONE_PACKAGE':['',86400000,'',false,0],'NV_THANKYOUTRACKCOOKIE':['.newegg.com',86400,'',false,0],'NV_CDICOOKIE':['.newegg.com',10800,'',false,0],'NV_CUSTOMERREVIEWCOOKIE':['',86400000,'',false,0],'NV_GOOGLE_ANALYTICS':['.newegg.com',2592000,'',false,0],'NV_DVINFO':['.newegg.com',0,'',false,0],'NV_THIRD_PARTY':['.newegg.com',2592000,'',false,0],'NV_NEWGOOGLE_ANALYTICS':['.newegg.com',2592000,'',false,0],'NV_CUSTOMERLOGININTERNALUSER':['.newegg.com',0,'',false,0],'NV_B2BCUSTOMERLOGIN':['.newegg.com',0,'',true,0],'NV_TESTCOOKIE':['.newegg.com',0,'',false,0],'NV_MyNeweggModule':['.newegg.com',2592000,'',false,0],'AB':['.newegg.com',0,'',false,0],'NV_SURVEY':['.newegg.com',2592000,'',false,0],'NV_CERTONA':['.newegg.com',86400,'',false,0],'NV_FV':['.newegg.com',0,'',false,0],'NV_GDPR':['.newegg.com',0,'',false,1],'NV_WISHLIST':['.newegg.com',2592000,'',false,0],'NV_COUNTRY':['.newegg.com',2592000,'',false,0],'NV_OTHERINFO':['.newegg.com',0,'',false,0],'NVTC':['.newegg.com',2592000,'',false,0],'NV_RECENTLYVIEWEDS':['.newegg.com',2592000,'',false,0],'NV_SPT':['.newegg.com',0,'',false,0],'NV_NEWEGGCOOKIE':['.newegg.com',0,'',false,0],'NV_LOCALSTORAGE':['.newegg.com',86400000,'',false,0],'NV_NID':['.newegg.com',2592000,'',false,0],'NV_W57':['.newegg.com',86400000,'',false,1],'NV_W62':['.newegg.com',86400000,'',false,1]},SiteCookieInfo:{bizUnit:"USA",enableReformattedCookie:true,writ ...
# <script crossorigin="anonymous" src="//c1.neweggimages.com/WebResource/Scripts/USA/Common/GgewenFramework.v1.w.30373.2.js" type="text/javascript"></script>
# <script crossorigin="anonymous" src="//c1.neweggimages.com/WebResource/Scripts/USA/Common/WebApplication.v1.w.14605.0.js" type="text/javascript"></script>
# <script crossorigin="anonymous" src="//c1.neweggimages.com/WebResource/Scripts/USA/Common/PageDisplayLib.v1.w.14072.0.js" type="text/javascript"></script>
# <script crossorigin="anonymous" src="//c1.neweggimages.com/WebResource/Scripts/USA/Common/AutoFilledKeywords.v1.w.30308.2.js" type="text/javascript"></script>
# <script crossorigin="anonymous" src="//c1.neweggimages.com/WebResource/Scripts/USA/Common/BizCommon.v1.w.30483.1.js" type="text/javascript"></script>
# <script crossorigin="anonymous" src="//c1.neweggimages.com/WebResource/Scripts/USA/Common/json2.min.js" type="text/javascript"></script>
# <script crossorigin="anonymous" src="//c1.neweggimages.com/WebResource/Scripts/USA/Common/swfobject.v1.5.js" type="text/javascript"></script>
# <script crossorigin="anonymous" src="//c1.neweggimages.com/WebResource/Scripts/USA/Common/swiper.min.3.4.2.js" type="text/javascript"></script>
# <script crossorigin="anonymous" src="//c1.neweggimages.com/WebResource/Scripts/USA/WWW/SearchPanel2016.v1.w.30250.1.js" type="text/javascript"></script>
# <script crossorigin="anonymous" src="//c1.neweggimages.com/WebResource/Scripts/USA/WWW/ProductList2016.v1.w.30308.0.js" type="text/javascript"></script>
# <script crossorigin="anonymous" src="//c1.neweggimages.com/WebResource/Scripts/USA/WWW/AutoConfiguratorStripe2016.v1.w.14413.0.js" type="text/javascript"></script>
# <script crossorigin="anonymous" src="//c1.neweggimages.com/WebResource/Scripts/USA/WWW/Store.v1.w.30308.0.js" type="text/javascript"></script>
# <script crossorigin="anonymous" src="//c1.neweggimages.com/WebResource/Scripts/USA/WWW/ProductCompare2019.v1.w.30462.0.js" type="text/javascript"></script>
# <!-- Begin Monetate ExpressTag Sync v8.1. Place at start of document head. DO NOT ALTER. -->
# <script type="text/javascript">var monetateT = new Date().getTime();</script>
# <script src="//se.monetate.net/js/2/a-f0e60b81/p/newegg.com/entry.js" type="text/javascript"></script>
# <!-- End Monetate tag. -->
# <script defer="" src="//imk.neweggimages.com/WebResource/Scripts/amber-lib-v7.js" type="text/javascript"></script>
# <script language="javascript" type="text/javascript">Web.Caching.SyncCookie('[{\"name\":\"NV_CONFIGURATION\",\"changeCookieValues\":[{\"key\":\"RegionCode\",\"value\":\"USA\"},{\"key\":\"CurrencyCode\",\"value\":\"USD\"},{\"key\":\"DEPA\",\"value\":\"1\"},{\"key\":\"Tid\",\"value\":\"6662\"}],\"expire\":0}]');</script>
# <script type="text/javascript">
#             Biz.Common.TopNavigation.saveOneDimensionCookie(Web.StateManager.Cookies.Name.REGION4CACHE, 'USA');
#             Biz.Common.TopNavigation.saveOneDimensionCookie(Web.StateManager.Cookies.Name.LANGUAGECODE, 'en');
#             </script>
# <script type="text/javascript">lbord=Math.random()*10000000000000000;</script>
# <script type="text/javascript">Biz.Product.video.isCookie('newegg');</script>
# <script type="text/javascript">if(top.location!=self.location){top.location.replace(self.location);}</script>
# <!--[if lt IE 9]><script type="text/javascript" src="//c1.neweggimages.com/WebResource/Scripts/USA/TP_Html5/Html5.js" crossorigin="anonymous"></script><![endif]-->
# </link></link></head>
# <body class="NEGlobal">
# <span class="noCSS">Skip to:</span>
# <a class="skiplink" href="#startContent">Content</a>
# <a name="startContent"><span style="display: none">|</span></a>
# <span class="noCSS">|</span>
# <a class="skiplink" href="#footerArea">Footer</a>
# <a name="top"></a>
# <div id="visionImpaired" style="position:absolute;left:0;top:-999px;"></div>
# <div id="message2OlderBrowser">
# <p>Newegg.com - A great place to buy computers, computer parts, electronics, software, accessories, and DVDs online. With great prices, fast shipping, and top-rated customer service - Newegg shopping upgraded ™</p>
# <p>If you are reading this message, <b>Please  <a href="javascript:void(0);" onclick="window.location = window.location.href;">click this link</a> to reload this page.(Do not use your browser's "Refresh" button).</b>  Please <a href="mailto:webmaster@newegg.com">email us</a> if you're running the latest version of your browser and you still see this message.</p>
# <p><a href="https://www.newegg.com/">Newegg.com - Computer Parts, Laptops, Electronics, HDTVs, Digital Cameras and More!</a></p>
# </div>
# <noscript>
# 	If you see this message, your web browser doesn't support JavaScript or JavaScript is disabled.
# 	Please enable JavaScript in your browser settings so Newegg.com can function correctly.
# 	</noscript>
# <!-- begin: header -->
# <header class="header">
# <div class="header-inner">
# <div class="header-logo">
# <a class="header-logo-img" href="https://www.newegg.com/" title="Newegg.com - Computer Parts, Laptops, Electronics, HDTVs, Digital Cameras and More!">
# <img alt="Newegg.com- Computer Parts, Laptops, Electronics, HDTVs, Digital Cameras and More!" src="//c1.neweggimages.com/WebResource/Themes/2005/Nest/logo_424x210.png"/></a>
# <div class="header-logo-bg"></div>
# </div>
# <!-- begin: header tabs -->
# <div class="header-tabs">
# <ul class="header-subsites">
# <li class="header-subsite">
# <a href="//www.neweggbusiness.com/?utm_medium=newegg&amp;utm_source=newegg-home&amp;cm_mmc=ref-newegg-_-newegg-home-_-na-_-na" target="_blank">
# <img alt="NeweggBusiness" src="//c1.neweggimages.com/WebResource/Themes/2005/Nest/new_tab_business.png"/>
# </a>
# </li>
# <li class="header-subsite">
# <a class="header-feedback" id="guest_feedback" onclick="javascript:newegg_inhouse_feedback &amp;&amp; newegg_inhouse_feedback.show();" style="cursor:pointer"><ins>Feedback</ins></a>
# </li>
# </ul>
# <div class="fix"></div>
# </div>
# <!-- end: header tabs -->
# <!-- begin: header top nav -->
# <nav class="top-nav">
# <input id="hiddenOrderInfo" is-update="0" name="hiddenOrderInfo" type="hidden" value=""/>
# <input id="switch_premier2016" type="hidden" value="True"/>
# <ul class="top-nav-tabs">
# <!--Region-->
# <!--Account-->
# <li class="top-nav-tab" id="usaSite">
# <script type="text/javascript">Biz.Common.TopNavigation.loginPageHeader2015();</script>
# </li>
# <!--ShoppingCart-->
# <li class="top-nav-tab" id="miniCart">
# <script type="text/javascript">prepareMiniCartInfo(true)</script>
# </li>
# <li class="top-nav-tab menu-align-right has-menu" id="liWishList">
# <a class="top-nav-tab-name" href="javascript:void(0);"><i class="top-nav-tab-icon fa fa-heart"></i><ins>Wish List</ins></a>
# <div class="top-nav-menu">
# <i class="fa fa-caret-down"></i><i class="top-nav-menu-arrow"></i>
# <div class="top-nav-menu-inner">
# <ul class="top-nav-menu-links">
# <li><a href="https://secure.newegg.com/WishList/MyWishlists">My Wish Lists</a></li>
# <li><a href="https://secure.newegg.com/WishList/FollowWishlists">Followed Wish Lists</a></li>
# <li><a href="https://secure.newegg.com/WishList/PublicWishlists">Public Wish Lists</a></li>
# </ul>
# </div>
# </div>
# </li>
# <script type="text/javascript">
#
#                 var wishlistPageUrlAlias = {
#                     WishListAjaxMiddlePage: "https://www.newegg.com/Common/Ajax/WishListAjaxMiddlePage.aspx",
#                     MyWishListDetail: "https://secure.newegg.com/Wishlist/MyWishlistDetail",
#                     MyWishLists: "https://secure.newegg.com/WishList/MyWishlists"
#                 };
#             </script>
# <script type="text/javascript">
#                      jQuery('#liWishList').bind('mouseover.loadWishlist', function () {
#                          jQuery("#liWishList").unbind("mouseover.loadWishlist");
#                          Biz.Common.TopNavigation.setWishlist(wishlistPageUrlAlias.WishListAjaxMiddlePage, wishlistPageUrlAlias.MyWishListDetail, wishlistPageUrlAlias.MyWishLists);
#                      });
#                  </script>
# <li class="top-nav-tab menu-align-right has-menu"><a class="top-nav-tab-name" href="javascript:void(0);"><i class="top-nav-tab-icon fa fa-question-circle"></i><ins>Customer Service</ins> </a>
# <div class="top-nav-menu">
# <i class="fa fa-caret-down"></i><i class="top-nav-menu-arrow"></i>
# <div class="top-nav-menu-inner">
# <ul class="top-nav-menu-links">
# <li><a href="https://secure.newegg.com/Guest/OrderLogin.aspx?Source=1" id="headerTrackOrder">Track An Order</a></li>
# <li><a href="https://secure.newegg.com/Guest/OrderLogin.aspx?Source=4" id="findInvoice">Find Invoice</a></li>
# <li><a href="https://secure.newegg.com/Guest/OrderLogin.aspx?Source=2" id="headerReturnItem">Return An Item</a></li>
# <li><a href="https://secure.newegg.com/Guest/OrderLogin.aspx?Source=3" id="checkReturnStatus">Check Return Status</a></li>
# <li><a href="//www.newegg.com/Special/Rebate.aspx?name=Rebate-Center">Find Rebates</a></li>
# <li class="top-nav-menu-split"><a href="https://kb.newegg.com/"><i class="fa fa-info-circle"></i> Help Center</a></li>
# </ul>
# </div>
# </div>
# </li>
# <li class="top-nav-tab top-country">
# <span class="top-nav-tab-name open-popup" data-source-id="Change_Country_Content" id="Change_Country">
# <span class="top-nav-tab-icon flag us"></span>
# <ins><span class="top-country-name">US</span><span class="top-country-language">EN</span></ins>
# </span>
# <div class="centerPopup-source" id="Change_Country_Content">
# <div class="fix text-center forchangecounrtypopup" style="display:none;">
# <h3 class="content"><strong class="seemslikefromtxt"></strong></h3>
# <p class="content">Do you want to visit Newegg website in your country?</p>
# </div>
# <div class="top-country-wrap" data-language="en" data-twolettercode="US">
# <div class="top-country-wrap-inner">
# <div class="list-box" data-container="Choose_Site_Continet">
# <label class="list-box-title">Area</label>
# <div class="list-box-inner">
# <ul></ul>
# </div>
# </div>
# <div class="list-box" data-container="Choose_Site_Country">
# <label class="list-box-title">Country/Region</label>
# <div class="list-box-inner">
# <ul></ul>
# </div>
# </div>
# <div class="list-box" data-container="Choose_Site_Language">
# <label class="list-box-title">Language</label>
# <div class="list-box-inner">
# <ul></ul>
# </div>
# </div>
# </div>
# <div class="top-country-bottom">
# <button class="btn forchangecounrtypopup" onclick="jQuery('.centerPopup-close:visible').click();" style="display:none;">Stay at United States</button>
# <button class="btn btn-primary nonchangecounrtypopup" onclick="Biz.Common.TopNavigation.RedirectToTargetRegion(jQuery('.centerPopup-close:visible'));">Save Preferences</button>
# <button class="btn btn-primary forchangecounrtypopup gotoregionbtn" onclick="Biz.Common.TopNavigation.RedirectToTargetRegion();" style="display:none;"></button>
# </div>
# </div>
# <p class="content text-center forchangecounrtypopup">International Shopping &amp; Shipping, <a href="//www.newegg.com/global" title="go to Newegg Global site">Newegg Global</a>.</p>
# </div>
# <script>
#                 var Newegg_Country_Language = [
#                 {
#                         "continet": "Africa",
#                         "country": [
#
#                         {
#                             "name": "Algeria",
#                             "countrycode": "DZA",
#                             "twolettercode": "dz",
#                             "localcurrency": "EUR",
#                             "language": ["EN"],
#                             "isdefualt":false
#                         }
#                         ,
#                         {
#                             "name": "Egypt",
#                             "countrycode": "EGY",
#                             "twolettercode": "eg",
#                             "localcurrency": "EGP",
#                             "language": ["EN"],
#                             "isdefualt":false
#                         }
#                         ,
#                         {
#                             "name": "Kenya",
#                             "countrycode": "KEN",
#                             "twolettercode": "ke",
#                             "localcurrency": "KES",
#                             "language": ["EN"],
#                             "isdefualt":false
#                         }
#                         ,
#                         {
#                             "name": "Morocco",
#                             "countrycode": "MAR",
#                             "twolettercode": "ma",
#                             "localcurrency": "MAD",
#                             "language": ["EN"],
#                             "isdefualt":false
#                         }
#                         ,
#                         {
#                             "name": "Nigeria",
#                             "countrycode": "NGA",
#                             "twolettercode": "ng",
#                             "localcurrency": "NGN",
#                             "language": ["EN"],
#                             "isdefualt":false
#                         }
#                         ,
#                         {
#                             "name": "South Africa",
#                             "countrycode": "ZAF",
#                             "twolettercode": "za",
#                             "localcurrency": "ZAR",
#                             "language": ["EN"],
#                             "isdefualt":false
#                         }
#                         ,
#                         {
#                             "name": "Tanzania",
#                             "countrycode": "TZA",
#                             "twolettercode": "tz",
#                             "localcurrency": "TZS",
#                             "language": ["EN"],
#                             "isdefualt":false
#                         }
#                         ,
#                         {
#                             "name": "Uganda",
#                             "countrycode": "UGA",
#                             "twolettercode": "ug",
#                             "localcurrency": "USD",
#                             "language": ["EN"],
#                             "isdefualt":false
#                         }
#
#                         ]},{
#                         "continet": "Asia",
#                         "country": [
#
#                         {
#                             "name": "Hong Kong",
#                             "countrycode": "HKG",
#                             "twolettercode": "hk",
#                             "localcurrency": "HKD",
#                             "language": ["EN"],
#                             "isdefualt":false
#                         }
#                         ,
#                         {
#                             "name": "India",
#                             "countrycode": "IND",
#                             "twolettercode": "in",
#                             "localcurrency": "INR",
#                             "language": ["EN"],
#                             "isdefualt":false
#                         }
#                         ,
#                         {
#                             "name": "Indonesia",
#                             "countrycode": "IDN",
#                             "twolettercode": "id",
#                             "localcurrency": "IDR",
#                             "language": ["EN"],
#                             "isdefualt":false
#                         }
#                         ,
#                         {
#                             "name": "Japan",
#                             "countrycode": "JPN",
#                             "twolettercode": "jp",
#                             "localcurrency": "JPY",
#                             "language": ["EN"],
#                             "isdefualt":false
#                         }
#                         ,
#                         {
#                             "name": "Kazakhstan",
#                             "countrycode": "KAZ",
#                             "twolettercode": "kz",
#                             "localcurrency": "KZT",
#                             "language": ["EN"],
#                             "isdefualt":false
#                         }
#                         ,
#                         {
#                             "name": "Macau",
#                             "countrycode": "MAC",
#                             "twolettercode": "mo",
#                             "localcurrency": "MOP",
#                             "language": ["EN"],
#                             "isdefualt":false
#                         }
#                         ,
#                         {
#                             "name": "Malaysia",
#                             "countrycode": "MYS",
#                             "twolettercode": "my",
#                             "localcurrency": "MYR",
#                             "language": ["EN"],
#                             "isdefualt":false
#                         }
#                         ,
#                         {
#                             "name": "Philippines",
#                             "countrycode": "PHL",
#                             "twolettercode": "ph",
#                             "localcurrency": "PHP",
#                             "language": ["EN"],
#                             "isdefualt":false
#                         }
#                         ,
#                         {
#                             "name": "Singapore",
#                             "countrycode": "SGP",
#                             "twolettercode": "sg",
#                             "localcurrency": "SGD",
#                             "language": ["EN"],
#                             "isdefualt":false
#                         }
#                         ,
#                         {
#                             "name": "South Korea",
#                             "countrycode": "KOR",
#                             "twolettercode": "kr",
#                             "localcurrency": "KRW",
#                             "language": ["EN"],
#                             "isdefualt":false
#                         }
#                         ,
#                         {
#                             "name": "Sri Lanka",
#                             "countrycode": "LKA",
#                             "twolettercode": "lk",
#                             "localcurrency": "LKR",
#                             "language": ["EN"],
#                             "isdefualt":false
#                         }
#                         ,
#                         {
#                             "name": "Taiwan",
#                             "countrycode": "TWN",
#                             "twolettercode": "tw",
#                             "localcurrency": "TWD",
#                             "language": ["EN"],
#                             "isdefualt":false
#                         }
#                         ,
#                         {
#                             "name": "Thailand",
#                             "countrycode": "THA",
#                             "twolettercode": "th",
#                             "localcurrency": "THB",
#                             "language": ["EN"],
#                             "isdefualt":false
#                         }
#                         ,
#                         {
#                             "name": "Vietnam",
#                             "countrycode": "VNM",
#                             "twolettercode": "vn",
#                             "localcurrency": "USD",
#                             "language": ["EN"],
#                             "isdefualt":false
#                         }
#
#                         ]},{
#                         "continet": "Central America & Caribbean",
#                         "country": [
#
#                         {
#                             "name": "Costa Rica",
#                             "countrycode": "CRI",
#                             "twolettercode": "cr",
#                             "localcurrency": "CRC",
#                             "language": ["EN","ES"],
#                             "isdefualt":false
#                         }
#                         ,
#                         {
#                             "name": "Dominican Republic",
#                             "countrycode": "DOM",
#                             "twolettercode": "do",
#                             "localcurrency": "DOP",
#                             "language": ["EN","ES"],
#                             "isdefualt":false
#                         }
#                         ,
#                         {
#                             "name": "El Salvador",
#                             "countrycode": "SLV",
#                             "twolettercode": "sv",
#                             "localcurrency": "USD",
#                             "language": ["EN","ES"],
#                             "isdefualt":false
#                         }
#                         ,
#                         {
#                             "name": "Honduras",
#                             "countrycode": "HND",
#                             "twolettercode": "hn",
#                             "localcurrency": "HNL",
#                             "language": ["EN","ES"],
#                             "isdefualt":false
#                         }
#                         ,
#                         {
#                             "name": "Jamaica",
#                             "countrycode": "JAM",
#                             "twolettercode": "jm",
#                             "localcurrency": "JMD",
#                             "language": ["EN"],
#                             "isdefualt":false
#                         }
#                         ,
#                         {
#                             "name": "Nicaragua",
#                             "countrycode": "NIC",
#                             "twolettercode": "ni",
#                             "localcurrency": "NIO",
#                             "language": ["EN","ES"],
#                             "isdefualt":false
#                         }
#                         ,
#                         {
#                             "name": "Panama",
#                             "countrycode": "PAN",
#                             "twolettercode": "pa",
#                             "localcurrency": "PAB",
#                             "language": ["EN","ES"],
#                             "isdefualt":false
#                         }
#
#                         ]},{
#                         "continet": "Europe",
#                         "country": [
#
#                         {
#                             "name": "Austria",
#                             "countrycode": "AUT",
#                             "twolettercode": "at",
#                             "localcurrency": "EUR",
#                             "language": ["EN"],
#                             "isdefualt":false
#                         }
#                         ,
#                         {
#                             "name": "Belgium",
#                             "countrycode": "BEL",
#                             "twolettercode": "be",
#                             "localcurrency": "EUR",
#                             "language": ["EN"],
#                             "isdefualt":false
#                         }
#                         ,
#                         {
#                             "name": "Bulgaria",
#                             "countrycode": "BGR",
#                             "twolettercode": "bg",
#                             "localcurrency": "BGN",
#                             "language": ["EN"],
#                             "isdefualt":false
#                         }
#                         ,
#                         {
#                             "name": "Croatia",
#                             "countrycode": "HRV",
#                             "twolettercode": "hr",
#                             "localcurrency": "HRK",
#                             "language": ["EN"],
#                             "isdefualt":false
#                         }
#                         ,
#                         {
#                             "name": "Czech Republic",
#                             "countrycode": "CZE",
#                             "twolettercode": "cz",
#                             "localcurrency": "CZK",
#                             "language": ["EN"],
#                             "isdefualt":false
#                         }
#                         ,
#                         {
#                             "name": "Denmark",
#                             "countrycode": "DNK",
#                             "twolettercode": "dk",
#                             "localcurrency": "DKK",
#                             "language": ["EN"],
#                             "isdefualt":false
#                         }
#                         ,
#                         {
#                             "name": "Finland",
#                             "countrycode": "FIN",
#                             "twolettercode": "fi",
#                             "localcurrency": "EUR",
#                             "language": ["EN"],
#                             "isdefualt":false
#                         }
#                         ,
#                         {
#                             "name": "France",
#                             "countrycode": "FRA",
#                             "twolettercode": "fr",
#                             "localcurrency": "EUR",
#                             "language": ["EN"],
#                             "isdefualt":false
#                         }
#                         ,
#                         {
#                             "name": "Germany",
#                             "countrycode": "DEU",
#                             "twolettercode": "de",
#                             "localcurrency": "EUR",
#                             "language": ["EN"],
#                             "isdefualt":false
#                         }
#                         ,
#                         {
#                             "name": "Greece",
#                             "countrycode": "GRC",
#                             "twolettercode": "gr",
#                             "localcurrency": "EUR",
#                             "language": ["EN"],
#                             "isdefualt":false
#                         }
#                         ,
#                         {
#                             "name": "Hungary",
#                             "countrycode": "HUN",
#                             "twolettercode": "hu",
#                             "localcurrency": "HUF",
#                             "language": ["EN"],
#                             "isdefualt":false
#                         }
#                         ,
#                         {
#                             "name": "Ireland",
#                             "countrycode": "IRL",
#                             "twolettercode": "ie",
#                             "localcurrency": "EUR",
#                             "language": ["EN"],
#                             "isdefualt":false
#                         }
#                         ,
#                         {
#                             "name": "Italy",
#                             "countrycode": "ITA",
#                             "twolettercode": "it",
#                             "localcurrency": "EUR",
#                             "language": ["EN"],
#                             "isdefualt":false
#                         }
#                         ,
#                         {
#                             "name": "Latvia",
#                             "countrycode": "LVA",
#                             "twolettercode": "lv",
#                             "localcurrency": "EUR",
#                             "language": ["EN"],
#                             "isdefualt":false
#                         }
#                         ,
#                         {
#                             "name": "Lithuania",
#                             "countrycode": "LTU",
#                             "twolettercode": "lt",
#                             "localcurrency": "EUR",
#                             "language": ["EN"],
#                             "isdefualt":false
#                         }
#                         ,
#                         {
#                             "name": "Luxembourg",
#                             "countrycode": "LUX",
#                             "twolettercode": "lu",
#                             "localcurrency": "EUR",
#                             "language": ["EN"],
#                             "isdefualt":false
#                         }
#                         ,
#                         {
#                             "name": "Monaco",
#                             "countrycode": "MCO",
#                             "twolettercode": "mc",
#                             "localcurrency": "EUR",
#                             "language": ["EN"],
#                             "isdefualt":false
#                         }
#                         ,
#                         {
#                             "name": "Netherlands",
#                             "countrycode": "NLD",
#                             "twolettercode": "nl",
#                             "localcurrency": "EUR",
#                             "language": ["EN"],
#                             "isdefualt":false
#                         }
#                         ,
#                         {
#                             "name": "Norway",
#                             "countrycode": "NOR",
#                             "twolettercode": "no",
#                             "localcurrency": "NOK",
#                             "language": ["EN"],
#                             "isdefualt":false
#                         }
#                         ,
#                         {
#                             "name": "Poland",
#                             "countrycode": "POL",
#                             "twolettercode": "pl",
#                             "localcurrency": "PLN",
#                             "language": ["EN"],
#                             "isdefualt":false
#                         }
#                         ,
#                         {
#                             "name": "Portugal",
#                             "countrycode": "PRT",
#                             "twolettercode": "pt",
#                             "localcurrency": "EUR",
#                             "language": ["EN"],
#                             "isdefualt":false
#                         }
#                         ,
#                         {
#                             "name": "Romania",
#                             "countrycode": "ROU",
#                             "twolettercode": "ro",
#                             "localcurrency": "RON",
#                             "language": ["EN"],
#                             "isdefualt":false
#                         }
#                         ,
#                         {
#                             "name": "Russia",
#                             "countrycode": "RUS",
#                             "twolettercode": "ru",
#                             "localcurrency": "RUB",
#                             "language": ["EN"],
#                             "isdefualt":false
#                         }
#                         ,
#                         {
#                             "name": "Serbia",
#                             "countrycode": "SRB",
#                             "twolettercode": "rs",
#                             "localcurrency": "RSD",
#                             "language": ["EN"],
#                             "isdefualt":false
#                         }
#                         ,
#                         {
#                             "name": "Slovakia",
#                             "countrycode": "SVK",
#                             "twolettercode": "sk",
#                             "localcurrency": "EUR",
#                             "language": ["EN"],
#                             "isdefualt":false
#                         }
#                         ,
#                         {
#                             "name": "Slovenia",
#                             "countrycode": "SVN",
#                             "twolettercode": "si",
#                             "localcurrency": "EUR",
#                             "language": ["EN"],
#                             "isdefualt":false
#                         }
#                         ,
#                         {
#                             "name": "Spain",
#                             "countrycode": "ESP",
#                             "twolettercode": "es",
#                             "localcurrency": "EUR",
#                             "language": ["EN","ES"],
#                             "isdefualt":false
#                         }
#                         ,
#                         {
#                             "name": "Sweden",
#                             "countrycode": "SWE",
#                             "twolettercode": "se",
#                             "localcurrency": "SEK",
#                             "language": ["EN"],
#                             "isdefualt":false
#                         }
#                         ,
#                         {
#                             "name": "Switzerland",
#                             "countrycode": "CHE",
#                             "twolettercode": "ch",
#                             "localcurrency": "CHF",
#                             "language": ["EN"],
#                             "isdefualt":false
#                         }
#                         ,
#                         {
#                             "name": "Turkey",
#                             "countrycode": "TUR",
#                             "twolettercode": "tr",
#                             "localcurrency": "TRY",
#                             "language": ["EN"],
#                             "isdefualt":false
#                         }
#                         ,
#                         {
#                             "name": "United Kingdom",
#                             "countrycode": "GBR",
#                             "twolettercode": "gb",
#                             "localcurrency": "GBP",
#                             "language": ["EN"],
#                             "isdefualt":false
#                         }
#
#                         ]},{
#                         "continet": "Middle East",
#                         "country": [
#
#                         {
#                             "name": "Bahrain",
#                             "countrycode": "BHR",
#                             "twolettercode": "bh",
#                             "localcurrency": "BHD",
#                             "language": ["EN"],
#                             "isdefualt":false
#                         }
#                         ,
#                         {
#                             "name": "Israel",
#                             "countrycode": "ISR",
#                             "twolettercode": "il",
#                             "localcurrency": "ILS",
#                             "language": ["EN"],
#                             "isdefualt":false
#                         }
#                         ,
#                         {
#                             "name": "Jordan",
#                             "countrycode": "JOR",
#                             "twolettercode": "jo",
# ...
# <img alt="Click for the BBB Business Review of this Computers - Supplies &amp; Parts in Whittier CA" src="//c1.neweggimages.com/WebResource/Themes/2005/Nest/blue-seal-newegginc.png" style="border: 0;">
# </img></a>
# <script src="https://sealserver.trustwave.com/seal.js?code=337bdba159684b989be28d750101ed87" type="text/javascript"></script><a class="noline" href="//www.newegg.com/Info/Awards.aspx" rel="nofollow">
# <img alt="Inc500" src="//c1.neweggimages.com/WebResource/Themes/2005/Nest/inc500.gif" style="border: 0;"/></a><span id="gtrust_badges"></span>
# </div>
# </footer>
# <!--footer area end-->
# <div class="footer-disclaimer">
# <a href="https://kb.newegg.com/knowledge-base/policy-agreement/" id="privacyPolicyUrl" rel="nofollow" target="_blank">
#                 Policy &amp; Agreement
#             </a>| <a href="https://kb.newegg.com/knowledge-base/privacy-policy-o/" id="policyAgreementUrl" rel="nofollow" target="_blank">
#                 Privacy Policy
#             </a>
# <span id="GDPRSpan" style="display:none">
#     | <a href="https://kb.newegg.com/knowledge-base/privacy-policy-o/#cookies" id="cookiePolicyUrl" rel="nofollow" target="_blank">
#         Cookie Policy
#     </a>| <a href="javascript:GDPRManageCookieClick();" rel="nofollow">
#         Manage Cookie
#     </a>| <a href="https://www.newegg.com/d/Info/YourInformation" rel="nofollow" target="_blank">
#         Your Information
#     </a></span> <script>
#             function GDPRManageCookieClick() {
#                 jQuery('#global-gdpr-Popup-All').click();
#                 Biz.Common.GDPR.popupInitForAll('popup-all-gdpr-marketing', 'popup-all-gdpr-third');
#             }
#     </script>
#
#
#
#  <span id="ieFontCheck" style="width:0px;">A</span>ll rights reserved.
#     </div>
# <ul class="social-follow-list">
# <li class="social-follow-item">
# <a aria-label="Facebook" class="fa fa-facebook social-follow-item-icon" href="https://www.facebook.com/Newegg" target="_blank"><span style="display: none">Facebook</span></a>
# </li>
# <li class="social-follow-item">
# <a aria-label="Twitter" class="fa fa-twitter social-follow-item-icon" href="https://twitter.com/Newegg" target="_blank"><span style="display: none">Twitter</span></a>
# </li>
# <li class="social-follow-item">
# <a aria-label="Instagram" class="fa fa-instagram social-follow-item-icon" href="https://www.instagram.com/newegg/" target="_blank"><span style="display: none">Instagram</span></a>
# </li>
# <li class="social-follow-item">
# <a aria-label="LinkedIn" class="fa fa-linkedin social-follow-item-icon" href="https://www.linkedin.com/company/newegg-com" target="_blank"><span style="display: none">LinkedIn</span></a>
# </li>
# <li class="social-follow-item">
# <a aria-label="Pinterest" class="fa fa-pinterest social-follow-item-icon" href="https://www.pinterest.com/newegg/" target="_blank"><span style="display: none">Pinterest</span></a>
# </li>
# <li class="social-follow-item">
# <a aria-label="YouTube" class="fa fa-youtube-play social-follow-item-icon" href="https://www.youtube.com/user/newegg" target="_blank"><span style="display: none">YouTube</span></a>
# </li>
# <li class="social-follow-item">
# <a aria-label="Twitch" class="fa fa-twitch social-follow-item-icon" href="https://www.twitch.tv/newegg" target="_blank"><span style="display: none">Twitch</span></a>
# </li>
# <li class="social-follow-item">
# <a aria-label="Discord" class="social-follow-item-icon" href="https://discordapp.com/invite/newegg" target="_blank"><img alt="Discord" src="//c1.neweggimages.com/WebResource/Themes/2005/Nest/Footer/SocialIcon/social_Discord.png"/><span style="display: none">Discord</span></a>
# </li>
# <li class="social-follow-item">
# <a aria-label="Mixer" class="social-follow-item-icon" href="https://mixer.com/newegg" target="_blank"><img alt="Mixer" src="//c1.neweggimages.com/WebResource/Themes/2005/Nest/Footer/SocialIcon/social_Mixer.png"/><span style="display: none">Mixer</span></a>
# </li>
# </ul>
# <div class="v655" id="overlay" style="display: none;">
# </div>
# <div class="v655" id="modal" style="display: none;">
# <span class="atnIcon icnInfo">
# <img alt="More Information" src="//c1.neweggimages.com/WebResource/Themes/2005/Nest/none.gif"/></span> <a class="atnIcon icnClose" href="javascript:void();" onclick="display.closeModal();">
# <img alt="close" src="//c1.neweggimages.com/WebResource/Themes/2005/Nest/none.gif">Close</img></a>
# <div class="content">
# </div>
# <img alt="loading" src="//c1.neweggimages.com/WebResource/Themes/2005/Nest/loading16.gif" style="display: none;">
# </img></div>
# <div class="v660">
# <div id="modalCommon" style="display: none;">
# <span class="atnIcon icnInfoNew" id="AlarmPanelNewCommon">
# <img alt="" class="iconNew" src="//c1.neweggimages.com/WebResource/Themes/2005/Nest/none.gif">
# <span class="title"></span></img></span><a class="atnIcon icnCloseNew" href="javascript:void(0);" onclick="Biz.Common.CommonPop.closePopup();">
# <img alt="close window" src="//c1.neweggimages.com/WebResource/Themes/2005/Nest/none.gif"/></a>
# <div class="content popUpLink" id="modalContent">
# </div>
# <div class="footer">
# <a href="javascript:void(0);" onclick="Biz.Common.CommonPop.closePopup();">
#                         close window
#                     </a>
# </div>
# </div>
# </div>
# <img alt="" height="0" src="//c1.neweggimages.com/WebResource/Themes/2005/Nest/Gomeznone2.gif" title="" width="0">
# <span style="display: none;">
#     If the Adobe Reader does not appear when you click on a link for a PDF file, you can <a href="https://www.adobe.com/products/acrobat/readstep.html">download Adobe Reader from the Adobe web site</a>.
# </span>
# <script type="text/javascript">
#     jQuery(document).ready(function () { Biz.Common.PageFooter.setLink(); });
# </script>
# <!--GDPR start-->
# <style>
#     .layout-wide .form-checkbox {
#         margin: 0;
#     }
# </style>
# <a class="open-popup" data-noexit="true" href="javascript:;" id="global-gdpr-Popup-MKT" style="display: none;"></a>
# <div class="centerPopup-source" id="global-gdpr-Popup-MKT_Content">
# <div class="centerPopup-title">
# <h2>Your Personal Data</h2>
# </div>
# <div class="centerPopup-normal-content">
# <p class="content">Newegg’s website and online services use cookies and similar technology for a number of reasons: Some technologies allow the site to function. These functional cookies are required to use the site and complete purchases. Another set of technologies improve the browsing experience and personalize it. Here are all the details about Newegg’s <a href="https://kb.newegg.com/Article/Index/12/3?id=2032#cookies" target="_blank">Cookie</a> and <a href="https://kb.newegg.com/Article/Index/12/3?id=2032" target="_blank">Privacy Policies</a>. Please select and accept your settings before you continue. Thank you.</p>
# <div class="form-cells">
# <div class="form-cell layout-wide">
# <label class="form-checkbox">
# <input checked="" disabled="" id="popup-mkt-gdpr-necessary" name="gdpr-category" type="checkbox" value="necessary"/>
# <span class="form-checkbox-title" style="color: #222;">Functional (required)</span>
# </label>
# </div>
# <div class="form-cell layout-wide">
# <label class="form-checkbox">
# <input id="popup-mkt-gdpr-marketing" name="gdpr-category" type="checkbox" value="personalized experience and offers"/>
# <span class="form-checkbox-title">Personalized Experience &amp; Offers (recommended)</span>
# </label>
# </div>
# </div>
# </div>
# <div class="centerPopup-bottom">
# <div class="centerPopup-button-area">
# <button class="btn btn-primary centerPopup-trigger-close" onclick="Biz.Common.GDPR.global_gdpr_popup_mkt_click()" type="button">I Agree</button>
# </div>
# </div>
# </div>
# <a class="open-popup" href="javascript:;" id="global-gdpr-Popup-All" style="display: none;"></a>
# <div class="centerPopup-source" id="global-gdpr-Popup-All_Content">
# <div class="centerPopup-title">
# <h2>Your Personal Data</h2>
# </div>
# <div class="centerPopup-normal-content">
# <p class="content">Newegg’s website and online services use cookies and similar technology for a number of reasons: Some technologies allow the site to function. These functional cookies are required to use the site and complete purchases. Another set of technologies improve the browsing experience and personalize it. Here are all the details about Newegg’s <a href="https://kb.newegg.com/Article/Index/12/3?id=2032#cookies" target="_blank">Cookie</a> and <a href="https://kb.newegg.com/Article/Index/12/3?id=2032" target="_blank">Privacy Policies</a>. Please select and accept your settings before you continue. Thank you.</p>
# <div class="form-cells">
# <div class="form-cell layout-wide">
# <label class="form-checkbox">
# <input checked="" disabled="" id="popup-all-gdpr-necessary" name="gdpr-category" type="checkbox" value="necessary"/>
# <span class="form-checkbox-title" style="color: #222;">Functional (required)</span>
# </label>
# </div>
# <div class="form-cell layout-wide">
# <label class="form-checkbox">
# <input id="popup-all-gdpr-marketing" name="gdpr-category" type="checkbox" value="personalized experience and offers"/>
# <span class="form-checkbox-title">Personalized Experience &amp; Offers (recommended)</span>
# </label>
# </div>
# <div class="form-cell layout-wide">
# <label class="form-checkbox">
# <input id="popup-all-gdpr-third" name="gdpr-category" type="checkbox" value="3rd party"/>
# <span class="form-checkbox-title">3rd Party (optional)</span>
# </label>
# </div>
# </div>
# </div>
# <div class="centerPopup-bottom">
# <div class="centerPopup-button-area">
# <button class="btn btn-primary centerPopup-trigger-close" onclick="Biz.Common.GDPR.global_gdpr_popup_all_click()" type="button">I Agree</button>
# </div>
# </div>
# </div>
# <a class="open-popup" href="javascript:;" id="global-gdpr-Popup-Trd" style="display: none;"></a>
# <div class="centerPopup-source" id="global-gdpr-Popup-Trd_Content">
# <div class="centerPopup-title">
# <h2>Your Personal Data</h2>
# </div>
# <div class="centerPopup-normal-content">
# <p class="content">To use this third-party content we need your approval to share your data with them. Here are all the details about Newegg’s <a href="https://kb.newegg.com/Article/Index/12/3?id=2032#cookies" target="_blank">Cookie</a> and <a href="https://kb.newegg.com/Article/Index/12/3?id=2032" target="_blank">Privacy Policies</a>. Please accept if you wish to continue with third-party features. Thank you.</p>
# <div class="form-cells">
# <div class="form-cell layout-wide">
# <label class="form-checkbox">
# <input id="popup-trd-gdpr-trd" name="gdpr-category" onchange="Biz.Common.GDPR.global_gdpr_popup_trd_checkBoxChange()" type="checkbox" value="3rd party"/>
# <span class="form-checkbox-title">3rd Party</span>
# </label>
# </div>
# </div>
# </div>
# <div class="centerPopup-bottom">
# <div class="centerPopup-button-area">
# <button class="btn btn-primary centerPopup-trigger-close" disabled="" id="popup-trd-gdpr-submit" onclick="Biz.Common.GDPR.global_gdpr_popup_trd_click();" type="button">I Agree</button>
# </div>
# </div>
# </div>
# <script>
#     Biz.Common.GDPR.checkNecessary(false);
# </script>
# <!--GDPR end-->
# <script>
# (function () {
#     if (typeof jQuery != 'undefined' && typeof jQuery.browser != 'undefined' && jQuery.browser.msie && parseInt(jQuery.browser.version) < 11) {
#         var msg = '<div style="padding:15px;color:#211e14;background-image:linear-gradient(#feefae, #fae692);border-bottom:1px solid #b3a569">' +
# '<h4>Please note that Newegg will stop supporting Internet Explorer ' + parseInt(jQuery.browser.version) + ' as of June 29, 2018.</h4>' +
# '<p>Newegg continually assesses the state of our existing solutions and looks for ways to make improvements. As part of our mission to protect customers and align with PCI DSS, Newegg updated the minimum TLS protocol required to access Newegg.com from TLS 1.0 to TLS 1.1. TLS 1.0 support is targeted for deprecation on June 29, 2018. We recommend <a href="https://www.microsoft.com/en-us/windows/microsoft-edge">Microsoft Edge</a>, <a href="https://chrome.google.com">Google Chrome</a>, or <a href="https://mozilla.org/firefox/">Firefox</a>.</p></p></div>';
#         jQuery('body').prepend(msg);
#     }
# })();
# !function () { if ("undefined" == typeof jQuery) { var e = document.createElement("img"); e.src = "//pf.newegg.com/tracking?entryType=jquery&name=undefined", document.body.appendChild(e) } }();
# </script>
# <!-- end: footer -->
# <!-- BEGIN SiteCatalyst --><script type="text/javascript">jQuery(document).ready(function () {var parms=[];var re1 = new RegExp('(\\?|&)?icid=([^&]*)');jQuery("a[href*='icid=']").each(function (n) {var m_name = re1.exec(jQuery(this).attr('href'));if (m_name!=null) { parms.push(m_name[2]);}});if (parms.length>0) {Biz.Common.SiteCatalyst.sendForOnClick({ 'prop21': parms.join(",")}, 'banner impression');}})</script><script type="text/javascript">var scp=typeof(scp)=='undefined'?{}:scp;scp.cmPageName="cat\x3a\x7bVideo Cards \x26 Video Devices\x7d";scp.serverName="E11WEB02";scp.pageType="Browsing;Store Browsing";scp.pageName="Home \x3e Components \x3e Video Cards \x26 Video Devices\x3acat";scp.searchType="";scp.tabStore="Components";scp.categoryStore="Video Cards \x26 Video Devices";scp.moreThan3level=false;scp.pageNickName="cat";if (typeof (s) != 'undefined') { Biz.Common.SiteCatalyst.send(scp); } else { document.getElementsByTagName('body')[0].addEventListener('eventFromScode', function (e) { Biz.Common.SiteCatalyst.send(scp); }, false); }</script><!-- END SiteCatalyst -->
# <!-- BEGIN: Google Trusted Store -->
# <script type="text/javascript">
# 					  var gts = gts || [];
#
# 					  gts.push(["id", "69025"]);
# 					  gts.push(["google_base_offer_id", ""]);
# 					  gts.push(["google_base_subaccount_id","8277688"]);
# 					  gts.push(["google_base_country","US"]);
# 					  gts.push(["google_base_language","en"]);
# 	          gts.push(["gtsContainer","gtrust_badges"]);
#
# 					  (function() {
# 						var scheme = (("https:" == document.location.protocol) ? "https://" : "http://");
# 						var gts = document.createElement("script");
# 						gts.type = "text/javascript";
# 						gts.async = true;
# 						gts.src = scheme + "www.googlecommerce.com/trustedstores/gtmp_compiled.js";
# 						var s = document.getElementsByTagName("script")[0];
# 						s.parentNode.insertBefore(gts, s);
# 					  })();
# 					</script>
# <!-- END: Google Trusted Store -->
# <script type="text/javascript">
#       var utag_data = {
#             page_breadcrumb:'Home &gt; Components &gt; Video Cards &amp; Video Devices',
#             page_tab_name:'Components',
#             page_category_name:'Video Cards &amp; Video Devices',
#             page_number:'0',
#             product_organic_skus:['N82E16814202278','N82E16814932212','N82E16814150795'],
#             page_type:'Category',
#             page_store_name:'CategoryStore',
#             site_region:'USA',
#             site_currency:'USD',
#             page_name:'StoreCategory',
#             search_scope:jQuery('#haQuickSearchStore option:selected').text(),
#             user_nvtc:Web.StateManager.Cookies.get(Web.StateManager.Cookies.Name.NVTC),
#             user_name:Web.StateManager.Cookies.get(Web.StateManager.Cookies.Name.LOGIN,'LOGINID6'),
#             third_party_render:['2a5e772a0f941c862180037f8a5c118c7abf2f7d']
#
#       };
#       var description = Biz.Common.QuickSearch.getUrlSearch('Description');
#       var d = Biz.Common.QuickSearch.getUrlSearch('d');
#       if(description)
#       {
#          utag_data.search_keyword = description;
#       }
#       else if(d)
#       {
#          utag_data.search_keyword = d;
#       }
#       </script>
# <script type="text/javascript">
#       (function(a,b,c,d){
#           a='//tags.tiqcdn.com/utag/newegg/newegg.com/prod/utag.js';
#           b=document;
#           c='script';
#           d=b.createElement(c);
#           d.src=a;
#           d.type='text/java'+c;
#           d.async=true;
#           a=b.getElementsByTagName(c)[0];
#           a.parentNode.insertBefore(d,a)
#       })();
#       </script>
# <script type="text/javascript">var store_data={storeTypeInt:'1',
# storeType:'category',
# storeID:'38',
# };</script>
# <script type="text/javascript">_satellite.pageBottom();</script>
# </img></body>
# </html>

# %% [markdown]
# ## Find all graphic cards which are in the featured box (all with class item-container)

# %%
videocards = page_soup.findAll("div", {"class":"item-container"})
# preview of all containers
videocards
# Out:
# [<div class="item-container">
#  <!--product image-->
#  <a class="item-img" href="https://www.newegg.com/sapphire-radeon-rx-580-100411p8gocl/p/N82E16814202278?Item=N82E16814202278">
#  <div class="item-badges">
#  </div>
#  <img alt="Sapphire PULSE Radeon RX 580 8GB GDDR5 PCI-E Dual HDMI / DVI-D / Dual DP OC w/ Backplate (UEFI), 100411P8GOCL" class="lazy-img" data-effect="fadeIn" data-src="//c1.neweggimages.com/NeweggImage/ProductImageCompressAll300/14-202-278-V05.jpg" src="//c1.neweggimages.com/WebResource/Themes/2005/Nest/blank.gif" title="Sapphire PULSE Radeon RX 580 8GB GDDR5 PCI-E Dual HDMI / DVI-D / Dual DP OC w/ Backplate (UEFI), 100411P8GOCL">
#  </img></a>
#  <div class="item-info">
#  <!--brand info-->
#  <div class="item-branding">
#  <a class="item-brand" href="https://www.newegg.com/Sapphire-Tech/BrandStore/ID-1561">
#  <img alt="Sapphire Tech" class="lazy-img" data-effect="fadeIn" data-src="//c1.neweggimages.com/Brandimage_70x28//Brand1561.gif" src="//c1.neweggimages.com/WebResource/Themes/2005/Nest/blank.gif" title="Sapphire Tech">
#  </img></a>
#  <!--rating info-->
#  <a class="item-rating" href="https://www.newegg.com/sapphire-radeon-rx-580-100411p8gocl/p/N82E16814202278?Item=N82E16814202278&amp;SortField=0&amp;SummaryType=0&amp;PageSize=10&amp;SelectedRating=-1&amp;VideoOnlyMark=False&amp;IsFeedbackTab=true#scrollFullInfo" title="Rating + 4"><i class="rating rating-4"></i><span class="item-rating-num">(83)</span></a>
#  </div>
#  <!--description info-->
#  <a class="item-title" href="https://www.newegg.com/sapphire-radeon-rx-580-100411p8gocl/p/N82E16814202278?Item=N82E16814202278" title="View Details"><i class="icon-premier icon-premier-xsm"></i>Sapphire PULSE Radeon RX 580 8GB GDDR5 PCI-E Dual HDMI / DVI-D / Dual DP OC w/ Backplate (UEFI), 100411P8GOCL</a>
#  <!--promption info-->
#  <p class="item-promo"><i class="item-promo-icon"></i>+ $10 off w/ promo code VGAPCJP423, limited offer</p>
#  <!--feature-->
#  <ul class="item-features">
#  <li><strong>Max Resolution:</strong> DisplayPort 1.4: 5120 x 2880 @ 60 Hz
#  HDMI: 4096 x 2160 @ 60 Hz
#  DL-DVI-D: 2560 x 1600 @ 60 Hz</li><li><strong>DisplayPort:</strong> 2 x DisplayPort 1.4</li><li><strong>DVI:</strong> 1 x DL-DVI-D</li><li><strong>HDMI:</strong> 2 x HDMI</li>
#  <li><strong>Model #: </strong>100411P8GOCL</li>
#  <li><strong>Item #: </strong>N82E16814202278</li>
#  </ul>
#  <div class="item-action">
#  <!--price-->
#  <ul class="price has-label-membership">
#  <li class="price-was">
#  </li>
#  <li class="price-map">
#  </li>
#  <li class="price-current">
#  <span class="price-current-label">
#  <a aria-label="Premier Price Explaination" class="membership-info membership-popup" data-neg-popid="MembershipPopup" href="javascript:void(0);" name="membership" style="display: inline"><span class="membership-icon"></span><span style="display: none">|</span></a>
#  </span>$<strong>184</strong><sup>.99</sup> <a class="price-current-num" href="https://www.newegg.com/sapphire-radeon-rx-580-100411p8gocl/p/N82E16814202278?Item=N82E16814202278&amp;buyingoptions=New">(17 Offers)</a>
#  <span class="price-current-range">
#  <abbr title="to">–</abbr>
#  </span>
#  </li>
#  <li class="price-save">
#  <span class="price-save-endtime price-save-endtime-current"></span>
#  <span class="price-save-endtime price-save-endtime-another" style="display:none;"></span>
#  </li>
#  <li class="price-note">
#  </li>
#  <li class="price-ship">
#          $3.99 Shipping
#      </li>
#  </ul>
#  <!--egg point-->
#  <!--financing-->
#  <!--buying-choices-->
#  <ul class="item-buying-choices">
#  <li>
#  <a href="https://www.newegg.com/sapphire-radeon-rx-580-100411p8gocl/p/N82E16814202278?Item=N82E16814202278&amp;buyingoptions=Used">
#  <label class="item-buying-choices-label">Used:</label>
#  <strong class="item-buying-choices-price">$199.99</strong>
#  <span class="item-buying-choices-num">(1 Offers)</span>
#  </a>
#  </li>
#  </ul>
#  <!--button-->
#  <div class="item-operate hidden-action-button">
#  <div class="item-button-area">
#  <button class="btn btn-mini" onclick="Javascript:Biz.ProductList.Item.add('https://www.newegg.com/sapphire-radeon-rx-580-100411p8gocl/p/N82E16814202278?Item=N82E16814202278');" title="View Details" type="button">View Details <i class="fa fa-caret-right"></i>
#  </button>
#  </div>
#  <!--compare-->
#  <div class="item-compare-box">
#  <label class="form-checkbox">
#  <input autocomplete="off" name="CompareItem" neg-itemnumber="14-202-278" type="checkbox" value="CompareItem_14-202-278"/>
#  <span class="form-checkbox-title">Compare</span>
#  </label>
#  </div>
#  <script type="text/javascript">
#
#                                  Biz.Product.CompareConfig2019.compareItems.push("14-202-278");
#                                  var itemThumbs = new Object();
#                                  itemThumbs.subCategoryId = 48;
#                                  itemThumbs.subCategoryDescription = "Desktop Graphics Cards";
#                                  itemThumbs.itemNumber = "14-202-278";
#                                  itemThumbs.imageUrl = "//c1.neweggimages.com/ProductImageCompressAll35/14-202-278-V05.jpg";
#                                  itemThumbs.description = "Sapphire PULSE Radeon RX 580 8GB GDDR5 PCI-E Dual HDMI &#47; DVI-D &#47; Dual DP OC w&#47; Backplate &#40;UEFI&#41;, 100411P8GOCL";
#                                  itemThumbs.productUrl = "/sapphire-radeon-rx-580-100411p8gocl/p/N82E16814202278?Item=N82E16814202278";
#                                  Biz.Product.CompareConfig2019.Thumbs.push(itemThumbs);
#
#                              Biz.Product.CompareConfig.compareItems.push("14-202-278");
#                              var itemThumbs = new Object();
#                              itemThumbs.itemNumber = "14-202-278";
#                              itemThumbs.imageUrl = "//c1.neweggimages.com/ProductImageCompressAll35/14-202-278-V05.jpg";
#                              Biz.Product.CompareConfig.Thumbs.push(itemThumbs);
#                          </script>
#  </div>
#  <!--ExtendWarranty PopUp-->
#  <input class="open-popup" id="ew_N82E16814202278" type="hidden">
#  <input class="open-popup" id="ew_MainItemFailedAddToCart_N82E16814202278" type="hidden">
#  </input></input></div>
#  </div>
#  <div class="item-stock" id="stock_14-202-278">
#  </div>
#  </div>, <div class="item-container">
#  <!--product image-->
#  <a class="item-img" href="https://www.newegg.com/gigabyte-geforce-rtx-2070-super-gv-n207sgaming-oc-8gd/p/N82E16814932212?Item=N82E16814932212">
#  <div class="item-badges">
#  </div>
#  <img alt="GIGABYTE GeForce RTX 2070 Super GAMING OC 3X 8G Graphics Card, 3 x WINDFORCE Fans, 8GB 256-Bit GDDR6, GV-N207SGAMING OC-8GD Video Card" class="lazy-img" data-effect="fadeIn" data-src="//c1.neweggimages.com/NeweggImage/ProductImageCompressAll300/14-932-212-V04.jpg" src="//c1.neweggimages.com/WebResource/Themes/2005/Nest/blank.gif" title="GIGABYTE GeForce RTX 2070 Super GAMING OC 3X 8G Graphics Card, 3 x WINDFORCE Fans, 8GB 256-Bit GDDR6, GV-N207SGAMING OC-8GD Video Card">
#  </img></a>
#  <div class="item-info">
#  <!--brand info-->
#  <div class="item-branding">
#  <a class="item-brand" href="https://www.newegg.com/GIGABYTE/BrandStore/ID-1314">
#  <img alt="GIGABYTE" class="lazy-img" data-effect="fadeIn" data-src="//c1.neweggimages.com/Brandimage_70x28//Brand1314.gif" src="//c1.neweggimages.com/WebResource/Themes/2005/Nest/blank.gif" title="GIGABYTE">
#  </img></a>
#  <!--rating info-->
#  <a class="item-rating" href="https://www.newegg.com/gigabyte-geforce-rtx-2070-super-gv-n207sgaming-oc-8gd/p/N82E16814932212?Item=N82E16814932212&amp;SortField=0&amp;SummaryType=0&amp;PageSize=10&amp;SelectedRating=-1&amp;VideoOnlyMark=False&amp;IsFeedbackTab=true#scrollFullInfo" title="Rating + 5"><i class="rating rating-5"></i><span class="item-rating-num">(8)</span></a>
#  </div>
#  <!--description info-->
#  <a class="item-title" href="https://www.newegg.com/gigabyte-geforce-rtx-2070-super-gv-n207sgaming-oc-8gd/p/N82E16814932212?Item=N82E16814932212" title="View Details"><i class="icon-premier icon-premier-xsm"></i>GIGABYTE GeForce RTX 2070 Super GAMING OC 3X 8G Graphics Card, GV-N207SGAMING OC-8GD</a>
#  <!--promption info-->
#  <p class="item-promo"><i class="item-promo-icon"></i>Buy GeForce RTX™, Get Call of Duty: Modern Warfare™, limited offer</p>
#  <!--feature-->
#  <ul class="item-features">
#  <li><strong>Core Clock:</strong> 1815 MHz</li><li><strong>Max Resolution:</strong> 7680 x 4320 @ 60 Hz</li><li><strong>DisplayPort:</strong> 3 x DisplayPort 1.4</li><li><strong>HDMI:</strong> 1 x HDMI 2.0b</li>
#  <li><strong>Model #: </strong>GV-N207SGAMINGOC-8GD</li>
#  <li><strong>Item #: </strong>N82E16814932212</li>
#  </ul>
#  <div class="item-action">
#  <!--price-->
#  <ul class="price has-label-membership">
#  <li class="price-was">
#  </li>
#  <li class="price-map">
#  </li>
#  <li class="price-current">
#  <span class="price-current-label">
#  <a aria-label="Premier Price Explaination" class="membership-info membership-popup" data-neg-popid="MembershipPopup" href="javascript:void(0);" name="membership" style="display: inline"><span class="membership-icon"></span><span style="display: none">|</span></a>
#  </span>$<strong>549</strong><sup>.99</sup> <a class="price-current-num" href="https://www.newegg.com/gigabyte-geforce-rtx-2070-super-gv-n207sgaming-oc-8gd/p/N82E16814932212?Item=N82E16814932212&amp;buyingoptions=New">(4 Offers)</a>
#  <span class="price-current-range">
#  <abbr title="to">–</abbr>
#  </span>
#  </li>
#  <li class="price-save">
#  <span class="price-save-endtime price-save-endtime-current"></span>
#  <span class="price-save-endtime price-save-endtime-another" style="display:none;"></span>
#  </li>
#  <li class="price-note">
#  </li>
#  <li class="price-ship">
#          Free Shipping
#      </li>
#  </ul>
#  <!--egg point-->
#  <!--financing-->
#  <!--button-->
#  <div class="item-operate hidden-action-button">
#  <div class="item-button-area">
#  <button class="btn btn-mini" onclick="Javascript:Biz.ProductList.Item.add('https://www.newegg.com/gigabyte-geforce-rtx-2070-super-gv-n207sgaming-oc-8gd/p/N82E16814932212?Item=N82E16814932212');" title="View Details" type="button">View Details <i class="fa fa-caret-right"></i>
#  </button>
#  </div>
#  <!--compare-->
#  <div class="item-compare-box">
#  <label class="form-checkbox">
#  <input autocomplete="off" name="CompareItem" neg-itemnumber="14-932-212" type="checkbox" value="CompareItem_14-932-212"/>
#  <span class="form-checkbox-title">Compare</span>
#  </label>
#  </div>
#  <script type="text/javascript">
#
#                                  Biz.Product.CompareConfig2019.compareItems.push("14-932-212");
#                                  var itemThumbs = new Object();
#                                  itemThumbs.subCategoryId = 48;
#                                  itemThumbs.subCategoryDescription = "Desktop Graphics Cards";
#                                  itemThumbs.itemNumber = "14-932-212";
#                                  itemThumbs.imageUrl = "//c1.neweggimages.com/ProductImageCompressAll35/14-932-212-V04.jpg";
#                                  itemThumbs.description = "GIGABYTE GeForce RTX 2070 Super GAMING OC 3X 8G Graphics Card, GV-N207SGAMING OC-8GD";
#                                  itemThumbs.productUrl = "/gigabyte-geforce-rtx-2070-super-gv-n207sgaming-oc-8gd/p/N82E16814932212?Item=N82E16814932212";
#                                  Biz.Product.CompareConfig2019.Thumbs.push(itemThumbs);
#
#                              Biz.Product.CompareConfig.compareItems.push("14-932-212");
#                              var itemThumbs = new Object();
#                              itemThumbs.itemNumber = "14-932-212";
#                              itemThumbs.imageUrl = "//c1.neweggimages.com/ProductImageCompressAll35/14-932-212-V04.jpg";
#                              Biz.Product.CompareConfig.Thumbs.push(itemThumbs);
#                          </script>
#  </div>
#  <!--ExtendWarranty PopUp-->
#  <input class="open-popup" id="ew_N82E16814932212" type="hidden">
#  <input class="open-popup" id="ew_MainItemFailedAddToCart_N82E16814932212" type="hidden">
#  </input></input></div>
#  </div>
#  <div class="item-stock" id="stock_14-932-212">
#  </div>
#  </div>, <div class="item-container">
#  <!--product image-->
#  <a class="item-img" href="https://www.newegg.com/xfx-radeon-rx-570-rx-570p427d6/p/N82E16814150795?Item=N82E16814150795">
#  <div class="item-badges">
#  </div>
#  <img alt="XFX RS XXX Edition Radeon RX 570 DirectX 12 RX-570P427D6 4GB OC+ 1284 MHz XFX Custom Backplate 256-Bit DDR5 PCI Express 3.0 CrossFireX Support Video Card" class="lazy-img" data-effect="fadeIn" data-src="//c1.neweggimages.com/NeweggImage/ProductImageCompressAll300/14-150-795-V01.jpg" src="//c1.neweggimages.com/WebResource/Themes/2005/Nest/blank.gif" title="XFX RS XXX Edition Radeon RX 570 DirectX 12 RX-570P427D6 4GB OC+ 1284 MHz XFX Custom Backplate 256-Bit DDR5 PCI Express 3.0 CrossFireX Support Video Card">
#  </img></a>
#  <div class="item-info">
#  <!--brand info-->
#  <div class="item-branding">
#  <a class="item-brand" href="https://www.newegg.com/XFX/BrandStore/ID-1669">
#  <img alt="XFX" class="lazy-img" data-effect="fadeIn" data-src="//c1.neweggimages.com/Brandimage_70x28//Brand1669.gif" src="//c1.neweggimages.com/WebResource/Themes/2005/Nest/blank.gif" title="XFX">
#  </img></a>
#  <!--rating info-->
#  <a class="item-rating" href="https://www.newegg.com/xfx-radeon-rx-570-rx-570p427d6/p/N82E16814150795?Item=N82E16814150795&amp;SortField=0&amp;SummaryType=0&amp;PageSize=10&amp;SelectedRating=-1&amp;VideoOnlyMark=False&amp;IsFeedbackTab=true#scrollFullInfo" title="Rating + 4"><i class="rating rating-4"></i><span class="item-rating-num">(19)</span></a>
#  </div>
#  <!--description info-->
#  <a class="item-title" href="https://www.newegg.com/xfx-radeon-rx-570-rx-570p427d6/p/N82E16814150795?Item=N82E16814150795" title="View Details"><i class="icon-premier icon-premier-xsm"></i>XFX RS XXX Edition Radeon RX 570 DirectX 12 RX-570P427D6 4GB OC+ 1284 MHz XFX Custom Backplate 256-Bit DDR5 PCI Express 3.0 CrossFireX Support Video Card</a>
#  <!--promption info-->
#  <p class="item-promo"><i class="item-promo-icon"></i>Get BL3 or Ghost Recon + 3 months of Xbox Game Pass w/ purchase, ends soon</p>
#  <!--feature-->
#  <ul class="item-features">
#  <li><strong>Core Clock:</strong> 1284 MHz (OC+ Capable Clock)
#  1264 MHz (XFX True Clock)
#  1168 MHz (AMD Reference)</li><li><strong>Max Resolution:</strong> 4096 x 2160</li><li><strong>DisplayPort:</strong> 3 x DisplayPort 1.4</li><li><strong>DVI:</strong> 1 x DL-DVI-D</li>
#  <li><strong>Model #: </strong>RX-570P427D6</li>
#  <li><strong>Item #: </strong>N82E16814150795</li>
#  </ul>
#  <div class="item-action">
#  <!--price-->
#  <ul class="price has-label-membership">
#  <li class="price-was">
#  </li>
#  <li class="price-map">
#  </li>
#  <li class="price-current">
#  <span class="price-current-label">
#  <a aria-label="Premier Price Explaination" class="membership-info membership-popup" data-neg-popid="MembershipPopup" href="javascript:void(0);" name="membership" style="display: inline"><span class="membership-icon"></span><span style="display: none">|</span></a>
#  </span>$<strong>129</strong><sup>.99</sup> <a class="price-current-num" href="https://www.newegg.com/xfx-radeon-rx-570-rx-570p427d6/p/N82E16814150795?Item=N82E16814150795&amp;buyingoptions=New">(2 Offers)</a>
#  <span class="price-current-range">
#  <abbr title="to">–</abbr>
#  </span>
#  </li>
#  <li class="price-save">
#  <span class="price-save-endtime price-save-endtime-current"></span>
#  <span class="price-save-endtime price-save-endtime-another" style="display:none;"></span>
#  </li>
#  <li class="price-note">
#  </li>
#  <li class="price-ship">
#          Free Shipping
#      </li>
#  </ul>
#  <!--egg point-->
#  <!--financing-->
#  <!--button-->
#  <div class="item-operate hidden-action-button">
#  <div class="item-button-area">
#  <button class="btn btn-mini" onclick="Javascript:Biz.ProductList.Item.add('https://www.newegg.com/xfx-radeon-rx-570-rx-570p427d6/p/N82E16814150795?Item=N82E16814150795');" title="View Details" type="button">View Details <i class="fa fa-caret-right"></i>
#  </button>
#  </div>
#  <!--compare-->
#  <div class="item-compare-box">
#  <label class="form-checkbox">
#  <input autocomplete="off" name="CompareItem" neg-itemnumber="14-150-795" type="checkbox" value="CompareItem_14-150-795"/>
#  <span class="form-checkbox-title">Compare</span>
#  </label>
#  </div>
#  <script type="text/javascript">
#
#                                  Biz.Product.CompareConfig2019.compareItems.push("14-150-795");
#                                  var itemThumbs = new Object();
#                                  itemThumbs.subCategoryId = 48;
#                                  itemThumbs.subCategoryDescription = "Desktop Graphics Cards";
#                                  itemThumbs.itemNumber = "14-150-795";
#                                  itemThumbs.imageUrl = "//c1.neweggimages.com/ProductImageCompressAll35/14-150-795-V01.jpg";
#                                  itemThumbs.description = "XFX RS XXX Edition Radeon RX 570 DirectX 12 RX-570P427D6 4GB OC&#43; 1284 MHz XFX Custom Backplate 256-Bit DDR5 PCI Express 3.0 CrossFireX Support Video Card";
#                                  itemThumbs.productUrl = "/xfx-radeon-rx-570-rx-570p427d6/p/N82E16814150795?Item=N82E16814150795";
#                                  Biz.Product.CompareConfig2019.Thumbs.push(itemThumbs);
#
#                              Biz.Product.CompareConfig.compareItems.push("14-150-795");
#                              var itemThumbs = new Object();
#                              itemThumbs.itemNumber = "14-150-795";
#                              itemThumbs.imageUrl = "//c1.neweggimages.com/ProductImageCompressAll35/14-150-795-V01.jpg";
#                              Biz.Product.CompareConfig.Thumbs.push(itemThumbs);
#                          </script>
#  </div>
#  <!--ExtendWarranty PopUp-->
#  <input class="open-popup" id="ew_N82E16814150795" type="hidden">
#  <input class="open-popup" id="ew_MainItemFailedAddToCart_N82E16814150795" type="hidden"/>
#  </input></div>
#  </div>
#  <div class="item-stock" id="stock_14-150-795">
#  </div>
#  </div>, <div class="item-container">
#  <!--product image-->
#  <a class="item-img" href="https://www.newegg.com/msi-geforce-rtx-2070-rtx-2070-gaming-8g/p/N82E16814137377?Item=N82E16814137377">
#  <div class="item-badges">
#  </div>
#  <img alt="MSI GeForce RTX 2070 DirectX 12 RTX 2070 GAMING 8G 8GB 256-Bit GDDR6 PCI Express 3.0 x16 HDCP Ready Video Card" class="lazy-img" data-effect="fadeIn" data-src="//c1.neweggimages.com/NeweggImage/ProductImageCompressAll300/14-137-377-V06.jpg" src="//c1.neweggimages.com/WebResource/Themes/2005/Nest/blank.gif" title="MSI GeForce RTX 2070 DirectX 12 RTX 2070 GAMING 8G 8GB 256-Bit GDDR6 PCI Express 3.0 x16 HDCP Ready Video Card">
#  </img></a>
#  <div class="item-info">
#  <!--brand info-->
#  <div class="item-branding">
#  <a class="item-brand" href="https://www.newegg.com/MSI/BrandStore/ID-1312">
#  <img alt="MSI" class="lazy-img" data-effect="fadeIn" data-src="//c1.neweggimages.com/Brandimage_70x28//Brand1312.gif" src="//c1.neweggimages.com/WebResource/Themes/2005/Nest/blank.gif" title="MSI">
#  </img></a>
#  <!--rating info-->
#  <a class="item-rating" href="https://www.newegg.com/msi-geforce-rtx-2070-rtx-2070-gaming-8g/p/N82E16814137377?Item=N82E16814137377&amp;SortField=0&amp;SummaryType=0&amp;PageSize=10&amp;SelectedRating=-1&amp;VideoOnlyMark=False&amp;IsFeedbackTab=true#scrollFullInfo" title="Rating + 5"><i class="rating rating-5"></i><span class="item-rating-num">(11)</span></a>
#  </div>
#  <!--description info-->
#  <a class="item-title" href="https://www.newegg.com/msi-geforce-rtx-2070-rtx-2070-gaming-8g/p/N82E16814137377?Item=N82E16814137377" title="View Details"><i class="icon-premier icon-premier-xsm"></i>MSI GeForce RTX 2070 DirectX 12 RTX 2070 GAMING 8G Video Card</a>
#  <!--promption info-->
#  <p class="item-promo"><i class="item-promo-icon"></i>Buy GeForce RTX™, Get Call of Duty: Modern Warfare™, limited offer</p>
#  <!--feature-->
#  <ul class="item-features">
#  <li><strong>Core Clock:</strong> 1410 MHz</li><li><strong>Max Resolution:</strong> 7680 x 4320</li><li><strong>DisplayPort:</strong> 3 x DisplayPort 1.4</li><li><strong>HDMI:</strong> 1 x HDMI 2.0b</li>
#  <li><strong>Model #: </strong>RTX 2070 GAMING 8G</li>
#  <li><strong>Item #: </strong>N82E16814137377</li>
#  </ul>
#  <div class="item-action">
#  <!--price-->
#  <ul class="price has-label-membership">
#  <li class="price-was">
#  </li>
#  <li class="price-map">
#  </li>
#  <li class="price-current">
#  <span class="price-current-label">
#  <a aria-label="Premier Price Explaination" class="membership-info membership-popup" data-neg-popid="MembershipPopup" href="javascript:void(0);" name="membership" style="display: inline"><span class="membership-icon"></span><span style="display: none">|</span></a>
#  </span>$<strong>489</strong><sup>.99</sup> <a class="price-current-num" href="https://www.newegg.com/msi-geforce-rtx-2070-rtx-2070-gaming-8g/p/N82E16814137377?Item=N82E16814137377&amp;buyingoptions=New">(2 Offers)</a>
#  <span class="price-current-range">
#  <abbr title="to">–</abbr>
#  </span>
#  </li>
#  <li class="price-save">
#  <span class="price-save-endtime price-save-endtime-current"></span>
#  <span class="price-save-endtime price-save-endtime-another" style="display:none;"></span>
#  </li>
#  <li class="price-note">
#  <span class="price-note-dollar" data-price="$474.99">$474.99</span>
#  <span class="price-note-label"> after </span>
#  <span class="price-note-dollar">$15.00</span>
#  <span class="price-note-label"> rebate card</span>
#  </li>
#  <li class="price-ship">
#          Free Shipping
#      </li>
#  </ul>
#  <!--egg point-->
#  <!--financing-->
#  <!--button-->
#  <div class="item-operate hidden-action-button">
#  <div class="item-button-area">
#  <button class="btn btn-mini" onclick="Javascript:Biz.ProductList.Item.add('https://www.newegg.com/msi-geforce-rtx-2070-rtx-2070-gaming-8g/p/N82E16814137377?Item=N82E16814137377');" title="View Details" type="button">View Details <i class="fa fa-caret-right"></i>
#  </button>
#  </div>
#  <!--compare-->
#  <div class="item-compare-box">
#  <label class="form-checkbox">
#  <input autocomplete="off" name="CompareItem" neg-itemnumber="14-137-377" type="checkbox" value="CompareItem_14-137-377"/>
#  <span class="form-checkbox-title">Compare</span>
#  </label>
#  </div>
#  <script type="text/javascript">
#
#                                  Biz.Product.CompareConfig2019.compareItems.push("14-137-377");
#                                  var itemThumbs = new Object();
#                                  itemThumbs.subCategoryId = 48;
#                                  itemThumbs.subCategoryDescription = "Desktop Graphics Cards";
#                                  itemThumbs.itemNumber = "14-137-377";
#                                  itemThumbs.imageUrl = "//c1.neweggimages.com/ProductImageCompressAll35/14-137-377-V06.jpg";
#                                  itemThumbs.description = "MSI GeForce RTX 2070 DirectX 12 RTX 2070 GAMING 8G Video Card";
#                                  itemThumbs.productUrl = "/msi-geforce-rtx-2070-rtx-2070-gaming-8g/p/N82E16814137377?Item=N82E16814137377";
#                                  Biz.Product.CompareConfig2019.Thumbs.push(itemThumbs);
#
#                              Biz.Product.CompareConfig.compareItems.push("14-137-377");
#                              var itemThumbs = new Object();
#                              itemThumbs.itemNumber = "14-137-377";
#                              itemThumbs.imageUrl = "//c1.neweggimages.com/ProductImageCompressAll35/14-137-377-V06.jpg";
#                              Biz.Product.CompareConfig.Thumbs.push(itemThumbs);
#                          </script>
#  </div>
#  <!--ExtendWarranty PopUp-->
#  <input class="open-popup" id="ew_N82E16814137377" type="hidden">
#  <input class="open-popup" id="ew_MainItemFailedAddToCart_N82E16814137377" type="hidden"/>
#  </input></div>
#  </div>
#  <div class="item-stock" id="stock_14-137-377">
#  </div>
#  </div>, <div class="item-container">
#  <!--product image-->
#  <a class="item-img" href="https://www.newegg.com/asus-geforce-rtx-2080-dual-rtx2080-a8g/p/N82E16814126269?Item=N82E16814126269">
#  <div class="item-badges">
#  </div>
#  <img alt="ASUS GeForce RTX 2080 Advanced Overclocked 8G GDDR6 Dual-Fan Edition VR Ready HDMI DP USB Type-C Graphics Card (DUAL-RTX2080-A8G)" class="lazy-img" data-effect="fadeIn" data-src="//c1.neweggimages.com/NeweggImage/ProductImageCompressAll300/14-126-269-V50.jpg" src="//c1.neweggimages.com/WebResource/Themes/2005/Nest/blank.gif" title="ASUS GeForce RTX 2080 Advanced Overclocked 8G GDDR6 Dual-Fan Edition VR Ready HDMI DP USB Type-C Graphics Card (DUAL-RTX2080-A8G)">
#  </img></a>
#  <div class="item-info">
#  <!--brand info-->
#  <div class="item-branding">
#  <a class="item-brand" href="https://www.newegg.com/ASUS/BrandStore/ID-1315">
#  <img alt="ASUS" class="lazy-img" data-effect="fadeIn" data-src="//c1.neweggimages.com/Brandimage_70x28//Brand1315.gif" src="//c1.neweggimages.com/WebResource/Themes/2005/Nest/blank.gif" title="ASUS">
#  </img></a>
#  <!--rating info-->
#  <a class="item-rating" href="https://www.newegg.com/asus-geforce-rtx-2080-dual-rtx2080-a8g/p/N82E16814126269?Item=N82E16814126269&amp;SortField=0&amp;SummaryType=0&amp;PageSize=10&amp;SelectedRating=-1&amp;VideoOnlyMark=False&amp;IsFeedbackTab=true#scrollFullInfo" title="Rating + 2"><i class="rating rating-2"></i><span class="item-rating-num">(1)</span></a>
#  </div>
#  <!--description info-->
#  <a class="item-title" href="https://www.newegg.com/asus-geforce-rtx-2080-dual-rtx2080-a8g/p/N82E16814126269?Item=N82E16814126269" title="View Details"><i class="icon-premier icon-premier-xsm"></i>ASUS GeForce RTX 2080 Advanced Overclocked 8G GDDR6 Dual-Fan Edition VR Ready HDMI DP USB Type-C Graphics Card (DUAL-RTX2080-A8G)</a>
#  <!--promption info-->
#  <p class="item-promo"><i class="item-promo-icon"></i>Buy GeForce RTX™, Get Call of Duty: Modern Warfare™, limited offer</p>
#  <!--feature-->
#  <ul class="item-features">
#  <li><strong>Core Clock:</strong> 1515 MHz</li><li><strong>Max Resolution:</strong> 7680 x 4320</li><li><strong>DisplayPort:</strong> 3 x DisplayPort 1.4</li><li><strong>HDMI:</strong> 1 x HDMI 2.0b</li>
#  <li><strong>Model #: </strong>DUAL-RTX2080-A8G</li>
#  <li><strong>Item #: </strong>N82E16814126269</li>
#  </ul>
#  <div class="item-action">
#  <!--price-->
#  <ul class="price has-label-membership">
#  <li class="price-was">
#  </li>
#  <li class="price-map">
#  </li>
#  <li class="price-current">
#  <span class="price-current-label">
#  <a aria-label="Premier Price Explaination" class="membership-info membership-popup" data-neg-popid="MembershipPopup" href="javascript:void(0);" name="membership" style="display: inline"><span class="membership-icon"></span><span style="display: none">|</span></a>
#  </span>$<strong>759</strong><sup>.99</sup> <a class="price-current-num" href="https://www.newegg.com/asus-geforce-rtx-2080-dual-rtx2080-a8g/p/N82E16814126269?Item=N82E16814126269&amp;buyingoptions=New">(8 Offers)</a>
#  <span class="price-current-range">
#  <abbr title="to">–</abbr>
#  </span>
#  </li>
#  <li class="price-save">
#  <span class="price-save-endtime price-save-endtime-current"></span>
#  <span class="price-save-endtime price-save-endtime-another" style="display:none;"></span>
#  </li>
#  <li class="price-note">
#  <span class="price-note-dollar" data-price="$729.99">$729.99</span>
#  <span class="price-note-label"> after </span>
#  <span class="price-note-dollar">$30.00</span>
#  <span class="price-note-label"> rebate card</span>
#  </li>
#  <li class="price-ship">
#          Free Shipping
#      </li>
#  </ul>
#  <!--egg point-->
#  <!--financing-->
#  <!--button-->
#  <div class="item-operate hidden-action-button">
#  <div class="item-button-area">
#  <button class="btn btn-mini" onclick="Javascript:Biz.ProductList.Item.add('https://www.newegg.com/asus-geforce-rtx-2080-dual-rtx2080-a8g/p/N82E16814126269?Item=N82E16814126269');" title="View Details" type="button">View Details <i class="fa fa-caret-right"></i>
#  </button>
#  </div>
#  <!--compare-->
#  <div class="item-compare-box">
#  <label class="form-checkbox">
#  <input autocomplete="off" name="CompareItem" neg-itemnumber="14-126-269" type="checkbox" value="CompareItem_14-126-269"/>
#  <span class="form-checkbox-title">Compare</span>
#  </label>
#  </div>
#  <script type="text/javascript">
#
#                                  Biz.Product.CompareConfig2019.compareItems.push("14-126-269");
#                                  var itemThumbs = new Object();
#                                  itemThumbs.subCategoryId = 48;
#                                  itemThumbs.subCategoryDescription = "Desktop Graphics Cards";
#                                  itemThumbs.itemNumber = "14-126-269";
#                                  itemThumbs.imageUrl = "//c1.neweggimages.com/ProductImageCompressAll35/14-126-269-V50.jpg";
#                                  itemThumbs.description = "ASUS GeForce RTX 2080 Advanced Overclocked 8G GDDR6 Dual-Fan Edition VR Ready HDMI DP USB Type-C Graphics Card &#40;DUAL-RTX2080-A8G&#41;";
#                                  itemThumbs.productUrl = "/asus-geforce-rtx-2080-dual-rtx2080-a8g/p/N82E16814126269?Item=N82E16814126269";
#                                  Biz.Product.CompareConfig2019.Thumbs.push(itemThumbs);
#
#                              Biz.Product.CompareConfig.compareItems.push("14-126-269");
#                              var itemThumbs = new Object();
#                              itemThumbs.itemNumber = "14-126-269";
#                              itemThumbs.imageUrl = "//c1.neweggimages.com/ProductImageCompressAll35/14-126-269-V50.jpg";
#                              Biz.Product.CompareConfig.Thumbs.push(itemThumbs);
#                          </script>
#  </div>
#  <!--ExtendWarranty PopUp-->
#  <input class="open-popup" id="ew_N82E16814126269" type="hidden">
#  <input class="open-popup" id="ew_MainItemFailedAddToCart_N82E16814126269" type="hidden"/>
#  </input></div>
#  </div>
#  <div class="item-stock" id="stock_14-126-269">
#  </div>
#  </div>, <div class="item-container">
#  <!--product image-->
#  <a class="item-img" href="https://www.newegg.com/evga-geforce-rtx-2070-super-08g-p4-3175-kr/p/N82E16814487477?Item=N82E16814487477">
#  <div class="item-badges">
#  </div>
#  <img alt="EVGA GeForce RTX 2070 SUPER XC ULTRA+ Video Card, OVERCLOCKED, 2.75-Slot Extreme Cool Dual, 70C Gaming, RGB, Metal Backplate, 08G-P4-3175-KR, 8GB 15.5 GHz GDDR6" class="lazy-img" data-effect="fadeIn" data-src="//c1.neweggimages.com/NeweggImage/ProductImageCompressAll300/14-487-477-V01.jpg" src="//c1.neweggimages.com/WebResource/Themes/2005/Nest/blank.gif" title="EVGA GeForce RTX 2070 SUPER XC ULTRA+ Video Card, OVERCLOCKED, 2.75-Slot Extreme Cool Dual, 70C Gaming, RGB, Metal Backplate, 08G-P4-3175-KR, 8GB 15.5 GHz GDDR6">
#  </img></a>
#  <div class="item-info">
#  <!--brand info-->
#  <div class="item-branding">
#  <a class="item-brand" href="https://www.newegg.com/EVGA/BrandStore/ID-1402">
#  <img alt="EVGA" class="lazy-img" data-effect="fadeIn" data-src="//c1.neweggimages.com/Brandimage_70x28//Brand1402.gif" src="//c1.neweggimages.com/WebResource/Themes/2005/Nest/blank.gif" title="EVGA">
#  </img></a>
#  <!--rating info-->
#  </div>
#  <!--description info-->
#  <a class="item-title" href="https://www.newegg.com/evga-geforce-rtx-2070-super-08g-p4-3175-kr/p/N82E16814487477?Item=N82E16814487477" title="View Details"><i class="icon-premier icon-premier-xsm"></i>EVGA GeForce RTX 2070 SUPER XC ULTRA+ Video Card, OVERCLOCKED, 2.75-Slot Extreme Cool Dual</a>
#  <!--promption info-->
#  <p class="item-promo"><i class="item-promo-icon"></i>Get Call of Duty: Modern Warfare™ w/ purchase, limited offer</p>
#  <!--feature-->
#  <ul class="item-features">
#  <li><strong>Max Resolution:</strong> 7680 x 4320</li><li><strong>DisplayPort:</strong> 3 x DisplayPort 1.4</li><li><strong>HDMI:</strong> 1 x HDMI 2.0b</li><li><strong>Card Dimensions (L x H):</strong> 10.62" x 4.38"</li>
#  <li><strong>Model #: </strong>08G-P4-3175-KR</li>
#  <li><strong>Item #: </strong>N82E16814487477</li>
#  </ul>
#  <div class="item-action">
#  <!--price-->
#  <ul class="price has-label-membership">
#  <li class="price-was">
#  </li>
#  <li class="price-map">
#  </li>
#  <li class="price-current">
#  <span class="price-current-label">
#  <a aria-label="Premier Price Explaination" class="membership-info membership-popup" data-neg-popid="MembershipPopup" href="javascript:void(0);" name="membership" style="display: inline"><span class="membership-icon"></span><span style="display: none">|</span></a>
#  </span>$<strong>604</strong><sup>.99</sup>
#              <span class="price-current-range">
#  <abbr title="to">–</abbr>
#  </span>
#  </li>
#  <li class="price-save">
#  <span class="price-save-endtime price-save-endtime-current"></span>
#  <span class="price-save-endtime price-save-endtime-another" style="display:none;"></span>
#  </li>
#  <li class="price-note">
#  <span class="price-note-dollar" data-price="$584.99">$584.99</span>
#  <span class="price-note-label"> after </span>
#  <span class="price-note-dollar">$20.00</span>
#  <span class="price-note-label"> rebate card</span>
#  </li>
#  <li class="price-ship">
#          Free Shipping
#      </li>
#  </ul>
#  <!--egg point-->
#  <!--financing-->
#  <!--button-->
#  <div class="item-operate hidden-action-button">
#  <div class="item-button-area">
#  <button class="btn btn-mini btn-primary" onclick="Biz.Product.video.conversion('cat\x3a\x7bVideo Cards \x26 Video Devices\x7d','14-487-477','1');Javascript:Biz.ProductList.Item.add('https://secure.newegg.com/Shopping/AddToCart.aspx?Submit=ADD&amp;ItemList=N82E16814487477');" title="Add EVGA GeForce RTX 2070 SUPER XC ULTRA+ Video Card, OVERCLOCKED, 2.75-Slot Extreme Cool Dual to cart" type="button">Add To Cart <i class="fa fa-caret-right"></i>
#  </button>
#  </div>
#  <!--compare-->
#  <div class="item-compare-box">
#  <label class="form-checkbox">
#  <input autocomplete="off" name="CompareItem" neg-itemnumber="14-487-477" type="checkbox" value="CompareItem_14-487-477"/>
#  <span class="form-checkbox-title">Compare</span>
#  </label>
#  </div>
#  <script type="text/javascript">
#
#                                  Biz.Product.CompareConfig2019.compareItems.push("14-487-477");
#                                  var itemThumbs = new Object();
#                                  itemThumbs.subCategoryId = 48;
#                                  itemThumbs.subCategoryDescription = "Desktop Graphics Cards";
#                                  itemThumbs.itemNumber = "14-487-477";
#                                  itemThumbs.imageUrl = "//c1.neweggimages.com/ProductImageCompressAll35/14-487-477-V01.jpg";
#                                  itemThumbs.description = "EVGA GeForce RTX 2070 SUPER XC ULTRA&#43; Video Card, OVERCLOCKED, 2.75-Slot Extreme Cool Dual";
#                                  itemThumbs.productUrl = "/evga-geforce-rtx-2070-super-08g-p4-3175-kr/p/N82E16814487477?Item=N82E16814487477";
#                                  Biz.Product.CompareConfig2019.Thumbs.push(itemThumbs);
#
#                              Biz.Product.CompareConfig.compareItems.push("14-487-477");
#                              var itemThumbs = new Object();
#                              itemThumbs.itemNumber = "14-487-477";
#                              itemThumbs.imageUrl = "//c1.neweggimages.com/ProductImageCompressAll35/14-487-477-V01.jpg";
#                              Biz.Product.CompareConfig.Thumbs.push(itemThumbs);
#                          </script>
#  </div>
#  <!--ExtendWarranty PopUp-->
#  <input class="open-popup" id="ew_N82E16814487477" type="hidden">
#  <input class="open-popup" id="ew_MainItemFailedAddToCart_N82E16814487477" type="hidden"/>
#  </input></div>
#  </div>
#  <div class="item-stock" id="stock_14-487-477">
#  </div>
#  </div>, <div class="item-container">
#  <!--product image-->
#  <a class="item-img" href="https://www.newegg.com/xfx-radeon-rx-5700-xt-rx-57xt826d6/p/N82E16814150824?Item=N82E16814150824">
#  <div class="item-badges">
#  </div>
#  <img alt="XFX Radeon RX 5700 XT THICC II RX-57XT826D6 8GB 256-Bit GDDR6 PCI Express 4.0 Video Card" class="lazy-img" data-effect="fadeIn" data-src="//c1.neweggimages.com/NeweggImage/ProductImageCompressAll300/14-150-824-V05.jpg" src="//c1.neweggimages.com/WebResource/Themes/2005/Nest/blank.gif" title="XFX Radeon RX 5700 XT THICC II RX-57XT826D6 8GB 256-Bit GDDR6 PCI Express 4.0 Video Card">
#  </img></a>
#  <div class="item-info">
#  <!--brand info-->
#  <div class="item-branding">
#  <a class="item-brand" href="https://www.newegg.com/XFX/BrandStore/ID-1669">
#  <img alt="XFX" class="lazy-img" data-effect="fadeIn" data-src="//c1.neweggimages.com/Brandimage_70x28//Brand1669.gif" src="//c1.neweggimages.com/WebResource/Themes/2005/Nest/blank.gif" title="XFX">
#  </img></a>
#  <!--rating info-->
#  <a class="item-rating" href="https://www.newegg.com/xfx-radeon-rx-5700-xt-rx-57xt826d6/p/N82E16814150824?Item=N82E16814150824&amp;SortField=0&amp;SummaryType=0&amp;PageSize=10&amp;SelectedRating=-1&amp;VideoOnlyMark=False&amp;IsFeedbackTab=true#scrollFullInfo" title="Rating + 5"><i class="rating rating-5"></i><span class="item-rating-num">(6)</span></a>
#  </div>
#  <!--description info-->
#  <a class="item-title" href="https://www.newegg.com/xfx-radeon-rx-5700-xt-rx-57xt826d6/p/N82E16814150824?Item=N82E16814150824" title="View Details"><i class="icon-premier icon-premier-xsm"></i>XFX Radeon RX 5700 XT THICC II RX-57XT826D6 8GB 256-Bit GDDR6 PCI Express 4.0 Video Card</a>
#  <!--promption info-->
#  <p class="item-promo"><i class="item-promo-icon"></i>Get BL3 or Ghost Recon + 3 months of Xbox Game Pass w/ purchase, ends soon</p>
#  <!--feature-->
#  <ul class="item-features">
#  <li><strong>Core Clock:</strong> 1605 MHz</li><li><strong>Max Resolution:</strong> 7680 x 4320</li><li><strong>DisplayPort:</strong> 3 x DisplayPort 1.4</li><li><strong>HDMI:</strong> 1 x HDMI 2.0b</li>
#  <li><strong>Model #: </strong>RX-57XT826D6</li>
#  <li><strong>Item #: </strong>N82E16814150824</li>
#  </ul>
#  <div class="item-action">
#  <!--price-->
#  <ul class="price has-label-membership">
#  <li class="price-was">
#  </li>
#  <li class="price-map">
#  </li>
#  <li class="price-current">
#  <span class="price-current-label">
#  <a aria-label="Premier Price Explaination" class="membership-info membership-popup" data-neg-popid="MembershipPopup" href="javascript:void(0);" name="membership" style="display: inline"><span class="membership-icon"></span><span style="display: none">|</span></a>
#  </span>$<strong>419</strong><sup>.99</sup>
#              <span class="price-current-range">
#  <abbr title="to">–</abbr>
#  </span>
#  </li>
#  <li class="price-save">
#  <span class="price-save-endtime price-save-endtime-current"></span>
#  <span class="price-save-endtime price-save-endtime-another" style="display:none;"></span>
#  </li>
#  <li class="price-note">
#  </li>
#  <li class="price-ship">
#          Free Shipping
#      </li>
#  </ul>
#  <!--egg point-->
#  <!--financing-->
#  <!--button-->
#  <div class="item-operate hidden-action-button">
#  <div class="item-button-area">
#  <button class="btn btn-mini" onclick="Javascript:Biz.ProductList.Item.add('https://www.newegg.com/xfx-radeon-rx-5700-xt-rx-57xt826d6/p/N82E16814150824?Item=N82E16814150824');" title="View Details" type="button">View Details <i class="fa fa-caret-right"></i>
#  </button>
#  </div>
#  <!--compare-->
#  <div class="item-compare-box">
#  <label class="form-checkbox">
#  <input autocomplete="off" name="CompareItem" neg-itemnumber="14-150-824" type="checkbox" value="CompareItem_14-150-824"/>
#  <span class="form-checkbox-title">Compare</span>
#  </label>
#  </div>
#  <script type="text/javascript">
#
#                                  Biz.Product.CompareConfig2019.compareItems.push("14-150-824");
#                                  var itemThumbs = new Object();
#                                  itemThumbs.subCategoryId = 48;
#                                  itemThumbs.subCategoryDescription = "Desktop Graphics Cards";
#                                  itemThumbs.itemNumber = "14-150-824";
#                                  itemThumbs.imageUrl = "//c1.neweggimages.com/ProductImageCompressAll35/14-150-824-V05.jpg";
#                                  itemThumbs.description = "XFX Radeon RX 5700 XT THICC II RX-57XT826D6 8GB 256-Bit GDDR6 PCI Express 4.0 Video Card";
#                                  itemThumbs.productUrl = "/xfx-radeon-rx-5700-xt-rx-57xt826d6/p/N82E16814150824?Item=N82E16814150824";
#                                  Biz.Product.CompareConfig2019.Thumbs.push(itemThumbs);
#
#                              Biz.Product.CompareConfig.compareItems.push("14-150-824");
#                              var itemThumbs = new Object();
#                              itemThumbs.itemNumber = "14-150-824";
#                              itemThumbs.imageUrl = "//c1.neweggimages.com/ProductImageCompressAll35/14-150-824-V05.jpg";
#                              Biz.Product.CompareConfig.Thumbs.push(itemThumbs);
#                          </script>
#  </div>
#  <!--ExtendWarranty PopUp-->
#  <input class="open-popup" id="ew_N82E16814150824" type="hidden">
#  <input class="open-popup" id="ew_MainItemFailedAddToCart_N82E16814150824" type="hidden"/>
#  </input></div>
#  </div>
#  <div class="item-stock" id="stock_14-150-824">
#  </div>
#  </div>, <div class="item-container">
#  <!--product image-->
#  <a class="item-img" href="https://www.newegg.com/gigabyte-radeon-rx-590-gv-rx590gaming-8gd/p/N82E16814932141?Item=N82E16814932141">
#  <div class="item-badges">
#  </div>
#  <img alt="GIGABYTE Radeon RX 590 Gaming 8G Graphics Card, 2 x WINDFORCE Fans, 8GB 256-Bit GDDR5, GV-RX590GAMING-8GD Video Card" class="lazy-img" data-effect="fadeIn" data-src="//c1.neweggimages.com/NeweggImage/ProductImageCompressAll300/14-932-141-Z01.jpg" src="//c1.neweggimages.com/WebResource/Themes/2005/Nest/blank.gif" title="GIGABYTE Radeon RX 590 Gaming 8G Graphics Card, 2 x WINDFORCE Fans, 8GB 256-Bit GDDR5, GV-RX590GAMING-8GD Video Card">
#  </img></a>
#  <div class="item-info">
#  <!--brand info-->
#  <div class="item-branding">
#  <a class="item-brand" href="https://www.newegg.com/GIGABYTE/BrandStore/ID-1314">
#  <img alt="GIGABYTE" class="lazy-img" data-effect="fadeIn" data-src="//c1.neweggimages.com/Brandimage_70x28//Brand1314.gif" src="//c1.neweggimages.com/WebResource/Themes/2005/Nest/blank.gif" title="GIGABYTE">
#  </img></a>
#  <!--rating info-->
#  <a class="item-rating" href="https://www.newegg.com/gigabyte-radeon-rx-590-gv-rx590gaming-8gd/p/N82E16814932141?Item=N82E16814932141&amp;SortField=0&amp;SummaryType=0&amp;PageSize=10&amp;SelectedRating=-1&amp;VideoOnlyMark=False&amp;IsFeedbackTab=true#scrollFullInfo" title="Rating + 4"><i class="rating rating-4"></i><span class="item-rating-num">(19)</span></a>
#  </div>
#  <!--description info-->
#  <a class="item-title" href="https://www.newegg.com/gigabyte-radeon-rx-590-gv-rx590gaming-8gd/p/N82E16814932141?Item=N82E16814932141" title="View Details"><i class="icon-premier icon-premier-xsm"></i>GIGABYTE Radeon RX 590 Gaming 8G Graphics Card, 2 x WINDFORCE Fans, 8GB 256-Bit GDDR5, GV-RX590GAMING-8GD Video Card</a>
#  <!--promption info-->
#  <p class="item-promo"><i class="item-promo-icon"></i>Get BL3 or Ghost Recon + 3 months of Xbox Game Pass w/ purchase, ends soon</p>
#  <!--feature-->
#  <ul class="item-features">
#  <li><strong>Core Clock:</strong> OC mode: 1560 MHz
#  Gaming mode: 1545 MHz</li><li><strong>Max Resolution:</strong> 7680 x 4320</li><li><strong>DisplayPort:</strong> 3 x DisplayPort</li><li><strong>DVI:</strong> 1 x Dual-link DVI-D</li>
#  <li><strong>Model #: </strong>GV-RX590GAMING-8GD</li>
#  <li><strong>Item #: </strong>N82E16814932141</li>
#  </ul>
#  <div class="item-action">
#  <!--price-->
#  <ul class="price has-label-membership">
#  <li class="price-was">
#  </li>
#  <li class="price-map">
#  </li>
#  <li class="price-current">
#  <span class="price-current-label">
#  <a aria-label="Premier Price Explaination" class="membership-info membership-popup" data-neg-popid="MembershipPopup" href="javascript:void(0);" name="membership" style="display: inline"><span class="membership-icon"></span><span style="display: none">|</span></a>
#  </span>$<strong>209</strong><sup>.99</sup> <a class="price-current-num" href="https://www.newegg.com/gigabyte-radeon-rx-590-gv-rx590gaming-8gd/p/N82E16814932141?Item=N82E16814932141&amp;buyingoptions=New">(3 Offers)</a>
#  <span class="price-current-range">
#  <abbr title="to">–</abbr>
#  </span>
#  </li>
#  <li class="price-save">
#  <span class="price-save-endtime price-save-endtime-current"></span>
#  <span class="price-save-endtime price-save-endtime-another" style="display:none;"></span>
#  </li>
#  <li class="price-note">
#  </li>
#  <li class="price-ship">
#          Free Shipping
#      </li>
#  </ul>
#  <!--egg point-->
#  <!--financing-->
#  <!--button-->
#  <div class="item-operate hidden-action-button">
#  <div class="item-button-area">
#  <button class="btn btn-mini" onclick="Javascript:Biz.ProductList.Item.add('https://www.newegg.com/gigabyte-radeon-rx-590-gv-rx590gaming-8gd/p/N82E16814932141?Item=N82E16814932141');" title="View Details" type="button">View Details <i class="fa fa-caret-right"></i>
#  </button>
#  </div>
#  <!--compare-->
#  <div class="item-compare-box">
#  <label class="form-checkbox">
#  <input autocomplete="off" name="CompareItem" neg-itemnumber="14-932-141" type="checkbox" value="CompareItem_14-932-141"/>
#  <span class="form-checkbox-title">Compare</span>
#  </label>
#  </div>
#  <script type="text/javascript">
#
#                                  Biz.Product.CompareConfig2019.compareItems.push("14-932-141");
#                                  var itemThumbs = new Object();
#                                  itemThumbs.subCategoryId = 48;
#                                  itemThumbs.subCategoryDescription = "Desktop Graphics Cards";
#                                  itemThumbs.itemNumber = "14-932-141";
#                                  itemThumbs.imageUrl = "//c1.neweggimages.com/ProductImageCompressAll35/14-932-141-Z01.jpg";
#                                  itemThumbs.description = "GIGABYTE Radeon RX 590 Gaming 8G Graphics Card, 2 x WINDFORCE Fans, 8GB 256-Bit GDDR5, GV-RX590GAMING-8GD Video Card";
#                                  itemThumbs.productUrl = "/gigabyte-radeon-rx-590-gv-rx590gaming-8gd/p/N82E16814932141?Item=N82E16814932141";
#                                  Biz.Product.CompareConfig2019.Thumbs.push(itemThumbs);
#
#                              Biz.Product.CompareConfig.compareItems.push("14-932-141");
#                              var itemThumbs = new Object();
#                              itemThumbs.itemNumber = "14-932-141";
#                              itemThumbs.imageUrl = "//c1.neweggimages.com/ProductImageCompressAll35/14-932-141-Z01.jpg";
#                              Biz.Product.CompareConfig.Thumbs.push(itemThumbs);
#                          </script>
#  </div>
#  <!--ExtendWarranty PopUp-->
#  <input class="open-popup" id="ew_N82E16814932141" type="hidden">
#  <input class="open-popup" id="ew_MainItemFailedAddToCart_N82E16814932141" type="hidden"/>
#  </input></div>
#  </div>
#  <div class="item-stock" id="stock_14-932-141">
#  </div>
#  </div>, <div class="item-container">
#  <!--product image-->
#  <a class="item-img" href="https://www.newegg.com/powercolor-radeon-rx-5700-xt-axrx-5700xt-8gbd6-3dhe-oc/p/N82E16814131752?Item=N82E16814131752">
#  <div class="item-badges">
#  </div>
#  <img alt="PowerColor RED DEVIL Radeon RX 5700 XT DirectX 12 AXRX 5700 XT 8GBD6-3DHE/OC 8GB 256-Bit GDDR6 PCI Express 4.0 CrossFireX Support ATX Video Card" class="lazy-img" data-effect="fadeIn" data-src="//c1.neweggimages.com/NeweggImage/ProductImageCompressAll300/14-131-752-V10.jpg" src="//c1.neweggimages.com/WebResource/Themes/2005/Nest/blank.gif" title="PowerColor RED DEVIL Radeon RX 5700 XT DirectX 12 AXRX 5700 XT 8GBD6-3DHE/OC 8GB 256-Bit GDDR6 PCI Express 4.0 CrossFireX Support ATX Video Card">
#  </img></a>
#  <div class="item-info">
#  <!--brand info-->
#  <div class="item-branding">
#  <a class="item-brand" href="https://www.newegg.com/PowerColor/BrandStore/ID-1419">
# ...
#  <p class="item-promo"></p>
#  <!--feature-->
#  <ul class="item-features">
#  <li><strong>Core Clock:</strong> 1506 MHz</li><li><strong>DisplayPort:</strong> 3 x DisplayPort 1.4</li><li><strong>DVI:</strong> 1 x DL-DVI-D</li><li><strong>HDMI:</strong> 1 x HDMI 2.0b</li>
#  <li><strong>Model #: </strong>ZT-P10620A-10M</li>
#  <li><strong>Item #: </strong>N82E16814500454</li>
#  </ul>
#  <div class="item-action">
#  <!--price-->
#  <ul class="price has-label-membership">
#  <li class="price-was">
#         $229.99
#              <span class="price-was-data" style="display: none">229.99</span>
#  </li>
#  <li class="price-map">
#  </li>
#  <li class="price-current">
#  <span class="price-current-label">
#  <a aria-label="Premier Price Explaination" class="membership-info membership-popup" data-neg-popid="MembershipPopup" href="javascript:void(0);" name="membership" style="display: inline"><span class="membership-icon"></span><span style="display: none">|</span></a>
#  </span>$<strong>209</strong><sup>.99</sup> <a class="price-current-num" href="https://www.newegg.com/zotac-geforce-gtx-1060-zt-p10620a-10m/p/N82E16814500454?Item=N82E16814500454&amp;buyingoptions=New">(6 Offers)</a>
#  <span class="price-current-range">
#  <abbr title="to">–</abbr>
#  </span>
#  </li>
#  <li class="price-save">
#  <span class="price-save-endtime price-save-endtime-current"><strong>Sale Ends in 2 Days (Mon)</strong> - </span>
#  <span class="price-save-endtime price-save-endtime-another" style="display:none;"><strong>Sale Ends in 10/28</strong> - </span>
#  <span class="price-save-label">Save: </span>
#  <span class="price-save-dollar"></span>
#  <span class="price-save-percent">9%</span>
#  </li>
#  <li class="price-note">
#  </li>
#  <li class="price-ship">
#          Free Shipping
#      </li>
#  </ul>
#  <!--egg point-->
#  <!--financing-->
#  <!--buying-choices-->
#  <ul class="item-buying-choices">
#  <li>
#  <a href="https://www.newegg.com/zotac-geforce-gtx-1060-zt-p10620a-10m/p/N82E16814500454?Item=N82E16814500454&amp;buyingoptions=Used">
#  <label class="item-buying-choices-label">Used:</label>
#  <strong class="item-buying-choices-price">$223.99</strong>
#  <span class="item-buying-choices-num">(1 Offers)</span>
#  </a>
#  </li>
#  </ul>
#  <!--button-->
#  <div class="item-operate hidden-action-button">
#  <div class="item-button-area">
#  <button class="btn btn-mini" onclick="Javascript:Biz.ProductList.Item.add('https://www.newegg.com/zotac-geforce-gtx-1060-zt-p10620a-10m/p/N82E16814500454?Item=N82E16814500454');" title="View Details" type="button">View Details <i class="fa fa-caret-right"></i>
#  </button>
#  </div>
#  <!--compare-->
#  <div class="item-compare-box">
#  <label class="form-checkbox">
#  <input autocomplete="off" name="CompareItem" neg-itemnumber="14-500-454" type="checkbox" value="CompareItem_14-500-454"/>
#  <span class="form-checkbox-title">Compare</span>
#  </label>
#  </div>
#  <script type="text/javascript">
#
#                                  Biz.Product.CompareConfig2019.compareItems.push("14-500-454");
#                                  var itemThumbs = new Object();
#                                  itemThumbs.subCategoryId = 48;
#                                  itemThumbs.subCategoryDescription = "Desktop Graphics Cards";
#                                  itemThumbs.itemNumber = "14-500-454";
#                                  itemThumbs.imageUrl = "//c1.neweggimages.com/ProductImageCompressAll35/14-500-454-V08.jpg";
#                                  itemThumbs.description = "ZOTAC GeForce GTX 1060 DirectX 12 ZT-P10620A-10M Video Card";
#                                  itemThumbs.productUrl = "/zotac-geforce-gtx-1060-zt-p10620a-10m/p/N82E16814500454?Item=N82E16814500454";
#                                  Biz.Product.CompareConfig2019.Thumbs.push(itemThumbs);
#
#                              Biz.Product.CompareConfig.compareItems.push("14-500-454");
#                              var itemThumbs = new Object();
#                              itemThumbs.itemNumber = "14-500-454";
#                              itemThumbs.imageUrl = "//c1.neweggimages.com/ProductImageCompressAll35/14-500-454-V08.jpg";
#                              Biz.Product.CompareConfig.Thumbs.push(itemThumbs);
#                          </script>
#  </div>
#  <!--ExtendWarranty PopUp-->
#  <input class="open-popup" id="ew_N82E16814500454" type="hidden">
#  <input class="open-popup" id="ew_MainItemFailedAddToCart_N82E16814500454" type="hidden"/>
#  </input></div>
#  </div>
#  <div class="item-stock" id="stock_14-500-454">
#  </div>
#  </div>, <div class="item-container">
#  <!--product image-->
#  <a class="item-img" href="https://www.newegg.com/asrock-radeon-vii-16g/p/N82E16814930012?Item=N82E16814930012">
#  <div class="item-badges">
#  </div>
#  <img alt="ASRock Phantom Gaming X Radeon VII DirectX 12 Radeon VII 16G 16GB 4096-Bit HBM2 PCI Express 3.0 x16 HDCP Ready Video Card" class="lazy-img" data-effect="fadeIn" data-src="//c1.neweggimages.com/NeweggImage/ProductImageCompressAll300/14-930-012-Z01.jpg" src="//c1.neweggimages.com/WebResource/Themes/2005/Nest/blank.gif" title="ASRock Phantom Gaming X Radeon VII DirectX 12 Radeon VII 16G 16GB 4096-Bit HBM2 PCI Express 3.0 x16 HDCP Ready Video Card">
#  </img></a>
#  <div class="item-info">
#  <!--brand info-->
#  <div class="item-branding">
#  <a class="item-brand" href="https://www.newegg.com/ASRock/BrandStore/ID-1944">
#  <img alt="ASRock" class="lazy-img" data-effect="fadeIn" data-src="//c1.neweggimages.com/Brandimage_70x28//Brand1944.gif" src="//c1.neweggimages.com/WebResource/Themes/2005/Nest/blank.gif" title="ASRock">
#  </img></a>
#  <!--rating info-->
#  <a class="item-rating" href="https://www.newegg.com/asrock-radeon-vii-16g/p/N82E16814930012?Item=N82E16814930012&amp;SortField=0&amp;SummaryType=0&amp;PageSize=10&amp;SelectedRating=-1&amp;VideoOnlyMark=False&amp;IsFeedbackTab=true#scrollFullInfo" title="Rating + 4"><i class="rating rating-4"></i><span class="item-rating-num">(18)</span></a>
#  </div>
#  <!--description info-->
#  <a class="item-title" href="https://www.newegg.com/asrock-radeon-vii-16g/p/N82E16814930012?Item=N82E16814930012" title="View Details"><i class="icon-premier icon-premier-xsm"></i>ASRock Phantom Gaming X Radeon VII DirectX 12 Radeon VII 16G Video Card</a>
#  <!--promption info-->
#  <p class="item-promo"><i class="item-promo-icon"></i>Get 3 months of Xbox Game Pass for PC with purchase, limited offer</p>
#  <!--feature-->
#  <ul class="item-features">
#  <li><strong>Core Clock:</strong> 1400 MHz</li><li><strong>Max Resolution:</strong> 7680 x 4320</li><li><strong>DisplayPort:</strong> 3 x DisplayPort 1.4</li><li><strong>HDMI:</strong> 1 x HDMI 2.0b</li>
#  <li><strong>Model #: </strong>PHANTOMXRADEON7</li>
#  <li><strong>Item #: </strong>N82E16814930012</li>
#  </ul>
#  <div class="item-action">
#  <!--price-->
#  <ul class="price has-label-membership">
#  <li class="price-was">
#  </li>
#  <li class="price-map">
#  </li>
#  <li class="price-current">
#  <span class="price-current-label">
#  <a aria-label="Premier Price Explaination" class="membership-info membership-popup" data-neg-popid="MembershipPopup" href="javascript:void(0);" name="membership" style="display: inline"><span class="membership-icon"></span><span style="display: none">|</span></a>
#  </span>$<strong>699</strong><sup>.99</sup>
#              <span class="price-current-range">
#  <abbr title="to">–</abbr>
#  </span>
#  </li>
#  <li class="price-save">
#  <span class="price-save-endtime price-save-endtime-current"></span>
#  <span class="price-save-endtime price-save-endtime-another" style="display:none;"></span>
#  </li>
#  <li class="price-note">
#  </li>
#  <li class="price-ship">
#          Free Shipping
#      </li>
#  </ul>
#  <!--egg point-->
#  <!--financing-->
#  <!--button-->
#  <div class="item-operate hidden-action-button">
#  <div class="item-button-area">
#  <button class="btn btn-mini btn-primary" onclick="Biz.Product.video.conversion('cat\x3a\x7bVideo Cards \x26 Video Devices\x7d','14-930-012','1');Javascript:Biz.ProductList.Item.add('https://secure.newegg.com/Shopping/AddToCart.aspx?Submit=ADD&amp;ItemList=N82E16814930012');" title="Add ASRock Phantom Gaming X Radeon VII DirectX 12 Radeon VII 16G Video Card to cart" type="button">Add To Cart <i class="fa fa-caret-right"></i>
#  </button>
#  </div>
#  <!--compare-->
#  <div class="item-compare-box">
#  <label class="form-checkbox">
#  <input autocomplete="off" name="CompareItem" neg-itemnumber="14-930-012" type="checkbox" value="CompareItem_14-930-012"/>
#  <span class="form-checkbox-title">Compare</span>
#  </label>
#  </div>
#  <script type="text/javascript">
#
#                                  Biz.Product.CompareConfig2019.compareItems.push("14-930-012");
#                                  var itemThumbs = new Object();
#                                  itemThumbs.subCategoryId = 48;
#                                  itemThumbs.subCategoryDescription = "Desktop Graphics Cards";
#                                  itemThumbs.itemNumber = "14-930-012";
#                                  itemThumbs.imageUrl = "//c1.neweggimages.com/ProductImageCompressAll35/14-930-012-Z01.jpg";
#                                  itemThumbs.description = "ASRock Phantom Gaming X Radeon VII DirectX 12 Radeon VII 16G Video Card";
#                                  itemThumbs.productUrl = "/asrock-radeon-vii-16g/p/N82E16814930012?Item=N82E16814930012";
#                                  Biz.Product.CompareConfig2019.Thumbs.push(itemThumbs);
#
#                              Biz.Product.CompareConfig.compareItems.push("14-930-012");
#                              var itemThumbs = new Object();
#                              itemThumbs.itemNumber = "14-930-012";
#                              itemThumbs.imageUrl = "//c1.neweggimages.com/ProductImageCompressAll35/14-930-012-Z01.jpg";
#                              Biz.Product.CompareConfig.Thumbs.push(itemThumbs);
#                          </script>
#  </div>
#  <!--ExtendWarranty PopUp-->
#  <input class="open-popup" id="ew_N82E16814930012" type="hidden">
#  <input class="open-popup" id="ew_MainItemFailedAddToCart_N82E16814930012" type="hidden"/>
#  </input></div>
#  </div>
#  <div class="item-stock" id="stock_14-930-012">
#  </div>
#  </div>, <div class="item-container">
#  <!--product image-->
#  <a class="item-img" href="https://www.newegg.com/msi-radeon-rx-570-rx-570-armor-8g-oc/p/N82E16814137256?Item=N82E16814137256">
#  <div class="item-badges">
#  </div>
#  <img alt="MSI Radeon RX 570 DirectX 12 RX 570 ARMOR 8G OC 8GB 256-Bit GDDR5 PCI Express x16 HDCP Ready CrossFireX Support ATX Video Card" class="lazy-img" data-effect="fadeIn" data-src="//c1.neweggimages.com/NeweggImage/ProductImageCompressAll300/14-137-256-V01.jpg" src="//c1.neweggimages.com/WebResource/Themes/2005/Nest/blank.gif" title="MSI Radeon RX 570 DirectX 12 RX 570 ARMOR 8G OC 8GB 256-Bit GDDR5 PCI Express x16 HDCP Ready CrossFireX Support ATX Video Card">
#  </img></a>
#  <div class="item-info">
#  <!--brand info-->
#  <div class="item-branding">
#  <a class="item-brand" href="https://www.newegg.com/MSI/BrandStore/ID-1312">
#  <img alt="MSI" class="lazy-img" data-effect="fadeIn" data-src="//c1.neweggimages.com/Brandimage_70x28//Brand1312.gif" src="//c1.neweggimages.com/WebResource/Themes/2005/Nest/blank.gif" title="MSI">
#  </img></a>
#  <!--rating info-->
#  <a class="item-rating" href="https://www.newegg.com/msi-radeon-rx-570-rx-570-armor-8g-oc/p/N82E16814137256?Item=N82E16814137256&amp;SortField=0&amp;SummaryType=0&amp;PageSize=10&amp;SelectedRating=-1&amp;VideoOnlyMark=False&amp;IsFeedbackTab=true#scrollFullInfo" title="Rating + 3"><i class="rating rating-3"></i><span class="item-rating-num">(103)</span></a>
#  </div>
#  <!--description info-->
#  <a class="item-title" href="https://www.newegg.com/msi-radeon-rx-570-rx-570-armor-8g-oc/p/N82E16814137256?Item=N82E16814137256" title="View Details"><i class="icon-premier icon-premier-xsm"></i>MSI Radeon RX 570 DirectX 12 RX 570 ARMOR 8G OC Video Card</a>
#  <!--promption info-->
#  <p class="item-promo"><i class="item-promo-icon"></i>+ $20 off w/ promo code VGASAV42A, limited offer</p>
#  <!--feature-->
#  <ul class="item-features">
#  <li><strong>Core Clock:</strong> 1268 MHz</li><li><strong>DisplayPort:</strong> 3 x DisplayPort</li><li><strong>DVI:</strong> 1 x DL-DVI-D</li><li><strong>HDMI:</strong> 1 x HDMI</li>
#  <li><strong>Model #: </strong>RX 570 ARMOR 8G OC</li>
#  <li><strong>Item #: </strong>N82E16814137256</li>
#  </ul>
#  <div class="item-action">
#  <!--price-->
#  <ul class="price has-label-membership">
#  <li class="price-was">
#  </li>
#  <li class="price-map">
#  </li>
#  <li class="price-current">
#  <span class="price-current-label">
#  <a aria-label="Premier Price Explaination" class="membership-info membership-popup" data-neg-popid="MembershipPopup" href="javascript:void(0);" name="membership" style="display: inline"><span class="membership-icon"></span><span style="display: none">|</span></a>
#  </span>$<strong>179</strong><sup>.99</sup> <a class="price-current-num" href="https://www.newegg.com/msi-radeon-rx-570-rx-570-armor-8g-oc/p/N82E16814137256?Item=N82E16814137256&amp;buyingoptions=New">(3 Offers)</a>
#  <span class="price-current-range">
#  <abbr title="to">–</abbr>
#  </span>
#  </li>
#  <li class="price-save">
#  <span class="price-save-endtime price-save-endtime-current"></span>
#  <span class="price-save-endtime price-save-endtime-another" style="display:none;"></span>
#  </li>
#  <li class="price-note">
#  <span class="price-note-dollar" data-price="$164.99">$164.99</span>
#  <span class="price-note-label"> after </span>
#  <span class="price-note-dollar">$15.00</span>
#  <span class="price-note-label"> rebate card</span>
#  </li>
#  <li class="price-ship">
#          Free Shipping
#      </li>
#  </ul>
#  <!--egg point-->
#  <!--financing-->
#  <!--button-->
#  <div class="item-operate hidden-action-button">
#  <div class="item-button-area">
#  <button class="btn btn-mini" onclick="Javascript:Biz.ProductList.Item.add('https://www.newegg.com/msi-radeon-rx-570-rx-570-armor-8g-oc/p/N82E16814137256?Item=N82E16814137256');" title="View Details" type="button">View Details <i class="fa fa-caret-right"></i>
#  </button>
#  </div>
#  <!--compare-->
#  <div class="item-compare-box">
#  <label class="form-checkbox">
#  <input autocomplete="off" name="CompareItem" neg-itemnumber="14-137-256" type="checkbox" value="CompareItem_14-137-256"/>
#  <span class="form-checkbox-title">Compare</span>
#  </label>
#  </div>
#  <script type="text/javascript">
#
#                                  Biz.Product.CompareConfig2019.compareItems.push("14-137-256");
#                                  var itemThumbs = new Object();
#                                  itemThumbs.subCategoryId = 48;
#                                  itemThumbs.subCategoryDescription = "Desktop Graphics Cards";
#                                  itemThumbs.itemNumber = "14-137-256";
#                                  itemThumbs.imageUrl = "//c1.neweggimages.com/ProductImageCompressAll35/14-137-256-V01.jpg";
#                                  itemThumbs.description = "MSI Radeon RX 570 DirectX 12 RX 570 ARMOR 8G OC Video Card";
#                                  itemThumbs.productUrl = "/msi-radeon-rx-570-rx-570-armor-8g-oc/p/N82E16814137256?Item=N82E16814137256";
#                                  Biz.Product.CompareConfig2019.Thumbs.push(itemThumbs);
#
#                              Biz.Product.CompareConfig.compareItems.push("14-137-256");
#                              var itemThumbs = new Object();
#                              itemThumbs.itemNumber = "14-137-256";
#                              itemThumbs.imageUrl = "//c1.neweggimages.com/ProductImageCompressAll35/14-137-256-V01.jpg";
#                              Biz.Product.CompareConfig.Thumbs.push(itemThumbs);
#                          </script>
#  </div>
#  <!--ExtendWarranty PopUp-->
#  <input class="open-popup" id="ew_N82E16814137256" type="hidden">
#  <input class="open-popup" id="ew_MainItemFailedAddToCart_N82E16814137256" type="hidden"/>
#  </input></div>
#  </div>
#  <div class="item-stock" id="stock_14-137-256">
#  </div>
#  </div>]

# %% [markdown]
# ## Print() product name and brand

# %%
for videocard in videocards:
    brand = videocard.find("div", {"class":"item-branding"}).img["title"]
    prodName = videocard.find("a",{"class":"item-title"}).getText()
    print("Brand: " + brand)
    print("Product: " + prodName )
# Out:
# Brand: Sapphire Tech
# Product: Sapphire PULSE Radeon RX 580 8GB GDDR5 PCI-E Dual HDMI / DVI-D / Dual DP OC w/ Backplate (UEFI), 100411P8GOCL
# Brand: GIGABYTE
# Product: GIGABYTE GeForce RTX 2070 Super GAMING OC 3X 8G Graphics Card, GV-N207SGAMING OC-8GD
# Brand: XFX
# Product: XFX RS XXX Edition Radeon RX 570 DirectX 12 RX-570P427D6 4GB OC+ 1284 MHz XFX Custom Backplate 256-Bit DDR5 PCI Express 3.0 CrossFireX Support Video Card
# Brand: MSI
# Product: MSI GeForce RTX 2070 DirectX 12 RTX 2070 GAMING 8G Video Card
# Brand: ASUS
# Product: ASUS GeForce RTX 2080 Advanced Overclocked 8G GDDR6 Dual-Fan Edition VR Ready HDMI DP USB Type-C Graphics Card (DUAL-RTX2080-A8G)
# Brand: EVGA
# Product: EVGA GeForce RTX 2070 SUPER XC ULTRA+ Video Card, OVERCLOCKED, 2.75-Slot Extreme Cool Dual
# Brand: XFX
# Product: XFX Radeon RX 5700 XT THICC II RX-57XT826D6 8GB 256-Bit GDDR6 PCI Express 4.0 Video Card
# Brand: GIGABYTE
# Product: GIGABYTE Radeon RX 590 Gaming 8G Graphics Card, 2 x WINDFORCE Fans, 8GB 256-Bit GDDR5, GV-RX590GAMING-8GD Video Card
# Brand: PowerColor
# Product: PowerColor RED DEVIL Radeon RX 5700 XT DirectX 12 AXRX 5700 XT 8GBD6-3DHE/OC Video Card
# Brand: ZOTAC
# Product: ZOTAC GeForce GTX 1060 DirectX 12 ZT-P10620A-10M Video Card
# Brand: ASRock
# Product: ASRock Phantom Gaming X Radeon VII DirectX 12 Radeon VII 16G Video Card
# Brand: MSI
# Product: MSI Radeon RX 570 DirectX 12 RX 570 ARMOR 8G OC Video Card

# %% [markdown]
# ### Vi byter ut product namnet till ett mer beskrivande namn
# ## Change the product name to a more describing name
#
# The title from the a-tag was not as describing as the title from the picture so lets use the picture title for the product name

# %%
for videocard in videocards:
    brand = videocard.find("div", {"class":"item-branding"}).img["title"]
    prodName = videocard.find("img",{"class":"lazy-img"})["title"]
    print("Brand: " + brand)
    print("Product: " + prodName )
    print()
# Out:
# Brand: Sapphire Tech
# Product: Sapphire PULSE Radeon RX 580 8GB GDDR5 PCI-E Dual HDMI / DVI-D / Dual DP OC w/ Backplate (UEFI), 100411P8GOCL
#
# Brand: GIGABYTE
# Product: GIGABYTE GeForce RTX 2070 Super GAMING OC 3X 8G Graphics Card, 3 x WINDFORCE Fans, 8GB 256-Bit GDDR6, GV-N207SGAMING OC-8GD Video Card
#
# Brand: XFX
# Product: XFX RS XXX Edition Radeon RX 570 DirectX 12 RX-570P427D6 4GB OC+ 1284 MHz XFX Custom Backplate 256-Bit DDR5 PCI Express 3.0 CrossFireX Support Video Card
#
# Brand: MSI
# Product: MSI GeForce RTX 2070 DirectX 12 RTX 2070 GAMING 8G 8GB 256-Bit GDDR6 PCI Express 3.0 x16 HDCP Ready Video Card
#
# Brand: ASUS
# Product: ASUS GeForce RTX 2080 Advanced Overclocked 8G GDDR6 Dual-Fan Edition VR Ready HDMI DP USB Type-C Graphics Card (DUAL-RTX2080-A8G)
#
# Brand: EVGA
# Product: EVGA GeForce RTX 2070 SUPER XC ULTRA+ Video Card, OVERCLOCKED, 2.75-Slot Extreme Cool Dual, 70C Gaming, RGB, Metal Backplate, 08G-P4-3175-KR, 8GB 15.5 GHz GDDR6
#
# Brand: XFX
# Product: XFX Radeon RX 5700 XT THICC II RX-57XT826D6 8GB 256-Bit GDDR6 PCI Express 4.0 Video Card
#
# Brand: GIGABYTE
# Product: GIGABYTE Radeon RX 590 Gaming 8G Graphics Card, 2 x WINDFORCE Fans, 8GB 256-Bit GDDR5, GV-RX590GAMING-8GD Video Card
#
# Brand: PowerColor
# Product: PowerColor RED DEVIL Radeon RX 5700 XT DirectX 12 AXRX 5700 XT 8GBD6-3DHE/OC 8GB 256-Bit GDDR6 PCI Express 4.0 CrossFireX Support ATX Video Card
#
# Brand: ZOTAC
# Product: ZOTAC GeForce GTX 1060 DirectX 12 ZT-P10620A-10M 6GB 192-Bit GDDR5X PCI Express 3.0 HDCP Ready Video Card
#
# Brand: ASRock
# Product: ASRock Phantom Gaming X Radeon VII DirectX 12 Radeon VII 16G 16GB 4096-Bit HBM2 PCI Express 3.0 x16 HDCP Ready Video Card
#
# Brand: MSI
# Product: MSI Radeon RX 570 DirectX 12 RX 570 ARMOR 8G OC 8GB 256-Bit GDDR5 PCI Express x16 HDCP Ready CrossFireX Support ATX Video Card

# %% [markdown]
# Done. Here we have a list of all the featured graphic cards from the page.
